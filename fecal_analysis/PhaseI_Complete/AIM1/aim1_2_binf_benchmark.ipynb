# %% [markdown]
# Overview

# %% [markdown]
# <h2> Project Set-up <h2>

# %%
#pkg_list=c("biomformat","ape","cowplot","data.table")
#pkg_list=c("dplyr","expss","ggplot2","ggpubr","phyloseq")
#pkg_list=c("scales","tibble","vegan","yaml","ggpubr","cluster","Hmisc","otuSummary")

for (pkg in pkg_list){
    print(citation(package=pkg))
}
# Out:
# To cite package 'biomformat' in publications use:
#
#   Paul J. McMurdie and Joseph N Paulson (2019). biomformat: An
#   interface package for the BIOM file format.
#   https://github.com/joey711/biomformat/, http://biom-format.org/.
#
# A BibTeX entry for LaTeX users is
#
#   @Manual{,
#     title = {biomformat: An interface package for the BIOM file format},
#     author = {Paul J. McMurdie and Joseph N Paulson},
#     year = {2019},
#     note = {https://github.com/joey711/biomformat/, http://biom-format.org/},
#   }
#
# ATTENTION: This citation information has been auto-generated from the
# package DESCRIPTION file and may need manual editing, see
# 'help("citation")'.
#
#
# To cite ape in a publication use:
#
#   Paradis E. & Schliep K. 2018. ape 5.0: an environment for modern
#   phylogenetics and evolutionary analyses in R. Bioinformatics 35:
#   526-528.
#
# A BibTeX entry for LaTeX users is
#
#   @Article{,
#     title = {ape 5.0: an environment for modern phylogenetics and evolutionary analyses in {R}},
#     author = {E. Paradis and K. Schliep},
#     journal = {Bioinformatics},
#     year = {2018},
#     volume = {35},
#     pages = {526-528},
#   }
#
# As ape is evolving quickly, you may want to cite also its version
# number (found with 'library(help = ape)' or 'packageVersion("ape")').
#
#
# To cite package 'cowplot' in publications use:
#
#   Claus O. Wilke (2019). cowplot: Streamlined Plot Theme and Plot
#   Annotations for 'ggplot2'. R package version 1.0.0.
#   https://CRAN.R-project.org/package=cowplot
#
# A BibTeX entry for LaTeX users is
#
#   @Manual{,
#     title = {cowplot: Streamlined Plot Theme and Plot Annotations for 'ggplot2'},
#     author = {Claus O. Wilke},
#     year = {2019},
#     note = {R package version 1.0.0},
#     url = {https://CRAN.R-project.org/package=cowplot},
#   }
#
#
# To cite package 'data.table' in publications use:
#
#   Matt Dowle and Arun Srinivasan (2019). data.table: Extension of
#   `data.frame`. R package version 1.12.8.
#   https://CRAN.R-project.org/package=data.table
#
# A BibTeX entry for LaTeX users is
#
#   @Manual{,
#     title = {data.table: Extension of `data.frame`},
#     author = {Matt Dowle and Arun Srinivasan},
#     year = {2019},
#     note = {R package version 1.12.8},
#     url = {https://CRAN.R-project.org/package=data.table},
#   }

# %%
source("sources/ggrare.R") #github library: https://rdrr.io/github/gauravsk/ranacapa/
source("sources/miseqR.R")
source("sources/qiime2R.R") #github https://github.com/jbisanz/qiime2R
source('sources/abundances.R') #github https://github.com/microbiome/microbiome

library(biomformat)
library(ape)
library(cowplot)
library(cluster)
library(data.table)
library(dplyr)
library("expss")
library(ggplot2)
library("ggpubr")
library(Hmisc)
library(otuSummary)
library(phyloseq)
library(scales)
library(tibble)
library(vegan)
library(yaml)
# Out:
# Warning message:
# "package 'ape' was built under R version 3.6.3"
# Warning message:
# "package 'cowplot' was built under R version 3.6.3"
#
# ********************************************************
#
# Note: As of version 1.0.0, cowplot does not change the
#
#   default ggplot2 theme anymore. To recover the previous
#
#   behavior, execute:
#   theme_set(theme_cowplot())
#
# ********************************************************
#
#
# Warning message:
# "package 'data.table' was built under R version 3.6.3"
# Warning message:
# "package 'dplyr' was built under R version 3.6.3"
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:data.table':
#
#     between, first, last
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# "package 'expss' was built under R version 3.6.3"
#
# Attaching package: 'expss'
#
#
# The following objects are masked from 'package:dplyr':
#
#     between, compute, contains, first, last, na_if, recode, vars
#
#
# The following objects are masked from 'package:data.table':
#
#     copy, like
#
#
# The following object is masked from 'package:ape':
#
#     where
#
#
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"
#
# Attaching package: 'ggplot2'
#
#
# The following object is masked from 'package:expss':
#
#     vars
#
#
# Warning message:
# "package 'ggpubr' was built under R version 3.6.3"
# Loading required package: magrittr
#
#
# Attaching package: 'magrittr'
#
#
# The following objects are masked from 'package:expss':
#
#     and, equals, or
#
#
#
# Attaching package: 'ggpubr'
#
#
# The following object is masked from 'package:expss':
#
#     compare_means
#
#
# The following object is masked from 'package:cowplot':
#
#     get_legend
#
#
# The following object is masked from 'package:ape':
#
#     rotate
#
#
# Warning message:
# "package 'tibble' was built under R version 3.6.3"
# Warning message:
# "package 'vegan' was built under R version 3.6.3"
# Loading required package: permute
#
# Warning message:
# "package 'permute' was built under R version 3.6.3"
# Loading required package: lattice
#
# Warning message:
# "package 'lattice' was built under R version 3.6.3"
# This is vegan 2.5-6
#
# Warning message:
# "package 'yaml' was built under R version 3.6.2"
# Warning message:
# "package 'cluster' was built under R version 3.6.3"
# Warning message:
# "package 'Hmisc' was built under R version 3.6.3"
# Loading required package: survival
#
# Warning message:
# "package 'survival' was built under R version 3.6.3"
# Loading required package: Formula
#
# Registered S3 methods overwritten by 'Hmisc':
#   method                 from
#   [.labelled             expss
#   print.labelled         expss
#   as.data.frame.labelled expss
#
#
# Attaching package: 'Hmisc'
#
#
# The following objects are masked from 'package:dplyr':
#
#     src, summarize
#
#
# The following object is masked from 'package:ape':
#
#     zoom
#
#
# The following objects are masked from 'package:base':
#
#     format.pval, units
#
#
# Warning message:
# "package 'otuSummary' was built under R version 3.6.3"

# %%
proj_dir='/Users/slsevilla/Google Drive/MyDocuments_Current/Education/George Mason University/Dissertation/Data/Aim1/'
out_dir=paste(proj_dir,'output/',sep="")
img_dir=paste(proj_dir,out_dir,'img/',sep="")

# %%
#Create file of all benchmarking files
benchmark_list = list.files(paste(out_dir,'taxonomic_classification',sep=""),pattern="(?:gg|SILVA|silva).qza")
write.csv(benchmark_list,paste(out_dir,'taxonomic_classification/summary.csv',sep=""))

# %%
#decide which files to include, add Y or N flag
benchmarkdf = read.csv(paste(out_dir,'taxonomic_classification/summary_in.csv',sep=""))
rownames(benchmarkdf) = benchmarkdf$x
benchmarkdf = benchmarkdf[c(-1)]
benchmarkdf = subset(benchmarkdf,include=="Y")
benchmarkdf
# Out:
#                            x                          group.type group.ref
# blast_cl_gg_gg.qza         blast_cl_gg_gg.qza         cl         gg
# scikit_clgg_gg.qza         scikit_clgg_gg.qza         cl         gg
# vsearch_cl_gg_gg.qza       vsearch_cl_gg_gg.qza       cl         gg
# blast_cl_SILVA_silva.qza   blast_cl_SILVA_silva.qza   cl         silva
# scikit_clSILVA_SILVA.qza   scikit_clSILVA_SILVA.qza   cl         silva
# vsearch_cl_SILVA_silva.qza vsearch_cl_SILVA_silva.qza cl         silva
# blast_dada_SILVA.qza       blast_dada_SILVA.qza       dada
# blast_dada_gg.qza          blast_dada_gg.qza          dada
# scikit_dada_SILVA.qza      scikit_dada_SILVA.qza      dada
# scikit_dada_gg.qza         scikit_dada_gg.qza         dada
# vsearch_dada_silva.qza     vsearch_dada_silva.qza     dada
# vsearch_dada_gg.qza        vsearch_dada_gg.qza        dada
# blast_dn_gg.qza            blast_dn_gg.qza            dn
# blast_dn_silva.qza         blast_dn_silva.qza         dn
# scikit_dn_SILVA.qza        scikit_dn_SILVA.qza        dn
# scikit_dn_gg.qza           scikit_dn_gg.qza           dn
# vsearch_dn_gg.qza          vsearch_dn_gg.qza          dn
# vsearch_dn_silva.qza       vsearch_dn_silva.qza       dn
# blast_op_gg_gg.qza         blast_op_gg_gg.qza         op         gg
# scikit_opgg_gg.qza         scikit_opgg_gg.qza         op         gg
# vsearch_op_gg_gg.qza       vsearch_op_gg_gg.qza       op         gg
# blast_op_SILVA_silva.qza   blast_op_SILVA_silva.qza   op         silva
# scikit_opSILVA_SILVA.qza   scikit_opSILVA_SILVA.qza   op         silva
# vsearch_op_SILVA_silva.qza vsearch_op_SILVA_silva.qza op         silva
#                            tax.type tax.ref include table.file
# blast_cl_gg_gg.qza         blast    gg      Y       table_cl_gg_0.99.qza
# scikit_clgg_gg.qza         scikit   gg      Y       table_cl_gg_0.99.qza
# vsearch_cl_gg_gg.qza       vsearch  gg      Y       table_cl_gg_0.99.qza
# blast_cl_SILVA_silva.qza   blast    silva   Y       table_cl_SILVA_0.99.qza
# scikit_clSILVA_SILVA.qza   scikit   silva   Y       table_cl_SILVA_0.99.qza
# vsearch_cl_SILVA_silva.qza vsearch  silva   Y       table_cl_SILVA_0.99.qza
# blast_dada_SILVA.qza       blast    silva   Y       table_dada_0.99.qza
# blast_dada_gg.qza          blast    gg      Y       table_dada_0.99.qza
# scikit_dada_SILVA.qza      scikit   silva   Y       table_dada_0.99.qza
# scikit_dada_gg.qza         scikit   gg      Y       table_dada_0.99.qza
# vsearch_dada_silva.qza     vsearch  silva   Y       table_dada_0.99.qza
# vsearch_dada_gg.qza        vsearch  gg      Y       table_dada_0.99.qza
# blast_dn_gg.qza            blast    gg      Y       table_dn_0.99.qza
# blast_dn_silva.qza         blast    silva   Y       table_dn_0.99.qza
# scikit_dn_SILVA.qza        scikit   silva   Y       table_dn_0.99.qza
# scikit_dn_gg.qza           scikit   gg      Y       table_dn_0.99.qza
# vsearch_dn_gg.qza          vsearch  gg      Y       table_dn_0.99.qza
# vsearch_dn_silva.qza       vsearch  silva   Y       table_dn_0.99.qza
# blast_op_gg_gg.qza         blast    gg      Y       table_op_gg_0.99.qza
# scikit_opgg_gg.qza         scikit   gg      Y       table_op_gg_0.99.qza
# vsearch_op_gg_gg.qza       vsearch  gg      Y       table_op_gg_0.99.qza
# blast_op_SILVA_silva.qza   blast    silva   Y       table_op_SILVA_0.99.qza
# scikit_opSILVA_SILVA.qza   scikit   silva   Y       table_op_SILVA_0.99.qza
# vsearch_op_SILVA_silva.qza vsearch  silva   Y       table_op_SILVA_0.99.qza

# %%
#Read in taxonomy file
CONTdf = read.csv('../taxonomy/Taxonomy_Complete.csv',stringsAsFactors = FALSE)

#Convert the tax file to SILVA naming with "D_5__"
CONTdf_s = CONTdf
for (i in 1:nrow(CONTdf)){
    old = as.character(CONTdf[i,"Genus"])
    new = paste("D_5__",old,sep="")
    new = gsub(" ", ".", new, fixed = TRUE)
    CONTdf_s[i,"Genus"] = new
    
    old = as.character(CONTdf[i,"Family"])
    new = paste("D_4__",old,sep="")
    new = gsub(" ", ".", new, fixed = TRUE)
    CONTdf_s[i,"Family"] = new
}

#Convert the tax file to gg naming with "f"
CONTdf_g = CONTdf
for (i in 1:nrow(CONTdf)){
    old = as.character(CONTdf[i,"Genus"])
    new = paste("g__",old,sep="")
    new = gsub(" ", ".", new, fixed = TRUE)
    CONTdf_g[i,"Genus"] = new
    
    old = as.character(CONTdf[i,"Family"])
    new = paste("f__",old,sep="")
    new = gsub(" ", ".", new, fixed = TRUE)
    CONTdf_g[i,"Family"] = new
}

# %% [markdown]
# <h2> Create PhyloSeq Object<h2>

# %%
phylo_create <- function(tax_in,tab_in){
    #Read OTUS
    otus<-read_qza(tab_in)

    #Read Greengenes taxonomy file
    taxonomy<-read_qza(tax_in)

    #Create taxonomy table
    tax_table = data.frame()
    col = 1
    row = 1

    for (i in taxonomy$data$Taxon){
        tax_list = as.list(strsplit(as.character(i),";"))
        for (i in 1:lengths(tax_list)){
            tax_table[row,col] = tax_list[[1]][i]
            col = col + 1
        }
        col = 1
        row = row + 1
    }
    rownames(tax_table)<-taxonomy$data$Feature.ID
    colnames(tax_table)<-c("Domain", "Phylum", "Class", "Order", "Family", "Genus", "Species")
    tax_convert<-as.matrix(tax_table)  

    #read metadata
    metadata<-read.table('../manifest/m_cleaned.txt',sep='\t', header=T, row.names=1, comment="")

    #Create phylo object
    phy_obj<-phyloseq(otu_table(otus$data, taxa_are_rows = T), tax_table(tax_convert), sample_data(metadata))
    print(phy_obj) 
    return(phy_obj)
}

# %%
phy_seq <- function(phy_in){
    #glom to tax level, subset for only seq controls
    seq_obj = tax_glom(phy_in,taxrank="Genus") #only merges genera that have the same upper taxonomy
    seq_obj = subset_samples(seq_obj,Sample.Type=="Seq_Control" & Sample.Des!="Seq_Blank")
    return(seq_obj)
}

# %%
otu_extract <- function(phy_in){
    # Extract abundance matrix from the phyloseq object
    OTU1 = as(otu_table(phy_in), "matrix")
    if(taxa_are_rows(phy_in)){OTU1 <- t(OTU1)} # transpose
    OTUdf = as.data.frame(OTU1)# Coerce to data.frame
    return(OTUdf)
}

# %%
tax_extract <- function(phy_in){
    #extract taxonomy information into dataframe
    TAXdf = tax_table(phy_in)
    return(TAXdf)
}

# %%
otu_tax_clean <- function(OTU_in,TAX_in){
    #Remove zero cols
    OTUdf_clean = OTU_in[, which(colSums(OTU_in) != 0)]

    #rename col from features to genus
    for (i in colnames(OTU_in)){
        newname = paste(as.character(TAX_in[i,"Family"]),as.character(TAX_in[i,"Genus"]),sep="")
        
        #standardize gg naming
        newname = trimws(newname) #remove first space in gg naming
        newname = sub(" g__","g__",newname)
        newname = sub("\\[","",newname)
        newname = sub("\\]","",newname)
        
        if(is.na(newname)){
            next;
        } else{
            names(OTUdf_clean)[names(OTUdf_clean) == i] <- newname
        }
    }
    
    #add metadata col
    metadata<-read.table('../manifest/m_cleaned.txt',sep='\t', header=T, row.names=1, comment="")
    for (a in rownames(OTUdf_clean)){
        OTUdf_clean[a,"Subject.ID"] = metadata[a,"Subject.ID"]
    }
    OTUdf_clean = data.frame(OTUdf_clean,stringsAsFactors=FALSE)
    
    return(OTUdf_clean)
}

# %%
#Create TP,FP,FN dataframe
bench_compare <- function(OTUdf_in,CONTdf_in){
    
    F1df = OTUdf_in
    F1df$Sample_names = rownames(F1df) #create col of sample_names
    
    #For each of the controls in the cleaned df
    for (cont in unique(OTUdf_in$Subject.ID)){
        temp=filter(CONTdf_in, get(cont) !=0) #create df of taxa related to control
        
        #Create taxa list, merging family and genus - this will help avoid id errors from taxonomic differences
        #IE one taxa labeled at the genus level may be from family1 and the same taxa may also be from family2
        taxa_list=list()
        for (x in rownames(temp)){taxa_list = c(taxa_list,paste(temp[x,"Family"],temp[x,"Genus"],sep=""))}  
        
        #Create list of samples that match the control
        sample_list = filter(F1df, Subject.ID == cont)$Sample_names
        
        #If the data is not in the df (FN), then add the taxa as a new col
        for (taxa in taxa_list){ 
            if(!(taxa %in% unique(colnames(F1df)))){
                F1df[taxa[!(taxa %in% colnames(F1df))]] = 0
            } 
        }

        for (sample in sample_list){
            for (col in unique(colnames(F1df))[unique(colnames(F1df)) != "Subject.ID" & unique(colnames(F1df)) != "Sample_names"]){ 
                #removes subjectID, sample_names cols from loop
                value_check = F1df[sample,col]

                if(col %in% taxa_list && value_check > 0){ #column matches expected taxa, has features
                    F1df[sample,col] = "TP"
                } else if (col %in% taxa_list && value_check == 0){ #column matches expected taxa, no features
                    F1df[sample,col] = "FN"
                } else if ((!col %in% taxa_list) && value_check > 0){ #column doesnt match expected taxa, has features
                    F1df[sample,col] = "FP"
                } else{ #column doesnt match expected taxa, has no features
                    next
                }
            }
        }
    }
    return(F1df)
}

# %%
#Create counts of FP, FN, TP
bench_counts <- function(OTUdf_in,F1_in,bmark_in,var_in){
    F1df_counts = subset(OTUdf_in, select=c("Subject.ID"))

    for (sample in rownames(F1df)){
        FN = rowSums(F1_in=="FN")[sample][[1]]
        FP = rowSums(F1_in=="FP")[sample][[1]]
        TP = rowSums(F1_in=="TP")[sample][[1]]

        F1df_counts[sample,"check"]= FN + TP
        F1df_counts[sample,"FN"] = FN
        F1df_counts[sample,"FP"] = FP
        F1df_counts[sample,"TP"] = TP
        F1df_counts[sample,"TAR"] = TP / (TP + FP)
        F1df_counts[sample,"TDR"] = TP / (TP + FN)

        num = F1df_counts[sample,"TAR"]*F1df_counts[sample,"TDR"]
        den = F1df_counts[sample,"TAR"]+F1df_counts[sample,"TDR"] 
        F1df_counts[sample,"F1"] = 2*(num/den)
        F1df_counts[sample,"Subject.ID"] = OTUdf_in[sample,"Subject.ID"]
        
        F1df_counts[sample,"bmark"] = bmark_in
        F1df_counts[sample,"group.type"] = benchmarkdf[variable,"group.type"]  
        F1df_counts[sample,"group.ref"] = benchmarkdf[variable,"group.ref"]
        F1df_counts[sample,"tax.type"] = benchmarkdf[variable,"tax.type"]
        F1df_counts[sample,"tax.ref"] = benchmarkdf[variable,"tax.ref"]
    }
    return(F1df_counts)
}

# %%
#F1_in=F1df_counts
bench_means <- function(F1_in){
    df = with(F1_in, tapply(X = FN,       
                    INDEX = Subject.ID,   
                    FUN = mean,     
                    na.rm = TRUE))
    return(df)
}

# %%
plot_violin <- function(df_in,x_lab,y_ax,y_lab,col_in){
    p = ggplot(df_in, aes(x=get(x_lab), y=get(y_ax), color=get(col_in))) + 
        geom_violin(trim=FALSE) + 
        labs(color = col_in) +
        theme(axis.text.x = element_text(angle = 90, hjust = 1),
              axis.title.x = element_blank(), 
             legend.position = "none") + 
        ylab(y_lab) +
        stat_summary(fun.data=mean_sdl, color="red")
    return (p)
}

# %%
plot_f1_violin <- function(F1_in,x_list,y_list,id_in,title,ftype){
    
    p_1 = plot_violin(F1_in,id_in,x_list[1],y_list[1],id_in)
    p_2 = plot_violin(F1_in,id_in,x_list[2],y_list[2],id_in)
    p_3 = plot_violin(F1_in,id_in,x_list[3],y_list[3],id_in)

    #Create count violin plots
    fig = ggarrange(p_1, p_2, p_3, 
              labels = c("A", "B", "C"),
              title = title,
              #common.legend = TRUE,
              ncol = 2, nrow = 2)
    annotate_figure(fig, #https://rpkgs.datanovia.com/ggpubr/reference/annotate_figure.html
                   top = text_grob(title, color = "blue", face = "bold", size = 14)
    )
    
    ggsave(paste(out_dir,"/img/violin_f1_",ftype,"_",title,".jpg",sep=""))
}

# %%
cal_relabun <- function(df_in){
    temp = df_in
    temp$Total = rowSums(df_in[,c(-(ncol(df_in)))])
    col_list = subset(colnames(temp),colnames(temp)!="Subject.ID" & colnames(temp)!="Total")

    #cal_relabund <- function(x){}
    for (row in rownames(temp)){
        for (col in col_list){
            val = temp[row,col]
            if(val==0){
                next
            } else{
                temp[row,col] = val/temp[row,"Total"]
            }
        }
    }
    return(temp)
}

# %% [markdown]
# <h2> Taxa Database <h2>

# %%
create_taxadf <- function(cont,contdf_in){
    taxdf=filter(contdf_in, get(cont) !=0) #create df of taxa related to control
    taxdf$taxa.id=paste(taxdf$Family,taxdf$Genus,sep="") #create fam/genus col
    taxdf = taxdf[,c("taxa.id",cont),drop=FALSE] #remove all cols but the merged and control col
    taxdf = aggregate(get(cont) ~ taxa.id, data = taxdf, sum) #collapse df for any dups    
    names(taxdf)[2] = cont
    rownames(taxdf) = taxdf$taxa.id
    return(taxdf)
}

# %% [markdown]
# <h2> Expected to Observed Correlation <h2>

# %%
cal_EO <- function(df_in,contdf_in,bench_in,title_in){
    count=1
    plot_list = list()
    EOdf_merged = data.frame()
    eo_out = data.frame()
    
    #For each of the controls in the cleaned df
    for (cont in unique(df_in$Subject.ID)){

        taxdf = create_taxadf(cont,contdf_in)
        taxa_list=taxdf$taxa.id
        
        #Create list of samples that match the control
        sample_list = filter(RAdf, Subject.ID == cont)$Sample_name
        EOdf= data.frame()
        
        for (taxa in taxa_list){
            for(sample in sample_list){
                EOdf[nrow(EOdf)+1,"Sample_name"] = sample
                EOdf[nrow(EOdf),"taxa.id"] = taxa
                EOdf[nrow(EOdf),"Subject.ID"] = cont
                EOdf[nrow(EOdf),"exp"] = taxdf[taxa,cont]
                EOdf[nrow(EOdf),"bench"] = bench_in

                if(is.null(df_in[sample,taxa])){
                    next
                } else{
                    EOdf[nrow(EOdf),"obs"] = df_in[sample,taxa]
                }
            }
        }
        EOdf_merged = rbind(EOdf_merged,EOdf) #Merge dfs
        
        #Create scatter plots
        plot_list[[count]] = plot_EO(EOdf,cont)
        count=count+1
        
        #Calc stats
        EOdf[is.na(EOdf)] = 0
        print(EOdf)
        temp = cal_EO_stattest(EOdf,cont,bench_in)
        eo_out = rbind(eo_out,temp) #merge df       
    }
    
    #print plots
    fig = ggarrange(plot_list[[1]], plot_list[[2]], plot_list[[3]], plot_list[[4]], plot_list[[5]], plot_list[[6]], 
              labels = c("A", "B", "C", "D", "E", "F"),
              #top = as.character(title_in),
              #common.legend = TRUE#,
              ncol = 2, nrow = 3)
    annotate_figure(fig, top = text_grob(title_in, color = "blue", face = "bold", size = 14)
    )
    ggsave(paste(out_dir,"/img/scatter_",bench_in,".jpg",sep=""))

    return(eo_out)
}

# %%
plot_EO <- function(df_in,cont_in){
    my_data=subset(df_in,Subject.ID==cont_in)

    p = ggscatter(my_data, x = "obs", y = "exp", 
              add = "reg.line", conf.int = TRUE, 
              cor.coef = TRUE, cor.method = "pearson",
              xlab = "Expected Rel Abunance (%)", ylab = "Observed Rel Abun (%)") +
        ggtitle(paste("Scatter plot of Rel Abun:",cont_in,sep=""))
    return(p)
}

# %%
cal_EO_stattest <- function(df_in,cont_in,bench_in){
    my_data=subset(df_in,Subject.ID==cont_in)
    df_out=data.frame()
    
    df_out[nrow(df_out)+1,"bmark"] = bench_in
    df_out[nrow(df_out),"cont"] = cont_in
    df_out[nrow(df_out),"shapiro"] = shapiro.test(my_data$obs)$p.value
    df_out[nrow(df_out),"spear.p"] = cor.test(my_data$obs,my_data$exp,method = "spearman")$p.value
    df_out[nrow(df_out),"spear.rho"] = cor.test(my_data$obs,my_data$exp,method = "spearman")$estimate[[1]]

    #-1 indicates a strong negative correlation : this means that every time x increases, y decreases (left panel figure)
    #0 means that there is no association between the two variables (x and y) (middle panel figure)
    #1 indicates a strong positive correlation : this means that y increases with x (right panel figure)
    return(df_out)
}

# %% [markdown]
# <h2>Dissimilarity <h2>

# %%
#Create averaged relative abundance df
create_av_RAdf <- function(RAdf_in,bench_in,var_in){
    tmp = aggregate(RAdf_in[,1:(ncol(RAdf_in)-3)], list(RAdf_in$Subject.ID), mean)
    tmp$bmark=bench_in
    tmp$db = benchmarkdf[var_in,"tax.ref"]
    return(tmp)
}

# %%
#Add expected values to RA average dfs
RAdf_addcontrols<-function(cont_in,df_in){
    
    tmp=get(df_in)
    cont_leng = length((unique(OTUdf_clean$Subject.ID)))
    
    for(i in 1:cont_leng){
        cont = as.character(tmp[i,"Group.1"])
        taxadf = create_taxadf(cont,get(cont_in))
        tmp_count = nrow(tmp)+1
        
        for(tx_row in 1:nrow(taxadf)){
            tmp[tmp_count,"Group.1"]=cont
            tmp[tmp_count,taxadf[tx_row,"taxa.id"]] = taxadf[tx_row,cont]
            tmp[tmp_count,"bmark"]="expected"
            tmp[tmp_count,"db"]=tmp[i,"db"]
        }
        
    }
    tmp[is.na(tmp)] = 0 
    return(tmp)
}

# %%
calc_dist <- function(RA_in,CONTdf_in){
    rownames(RA_in)=paste(RA_in$Group.1,RA_in$bmark,sep="-")
    RA_in = subset(RA_in, select = -c(db,Group.1,bmark))

    taxa_list<-unique(paste(CONTdf_in$Family,CONTdf_in$Genus,sep=""))
    df_clean = RA_in[,colnames(RA_in) %in% taxa_list] #remove cols not expected

    df_out = vegdist(df_clean,method="bray")   
    return(df_out)
}

# %%
plot_dist_cluster <- function(df_in,ref_in){
    fname = paste(out_dir,"/img/hclust_summary_bc_allgroups_",ref_in,".png",sep="")
    png(fname,width = 900, height = 600)
    p = plot(hclust(df_in), cex = .9, main = "All Groups - Bray-Curtis Dissimilarity",
             xlab="Bioinformatic Variables", sub="")
    dev.off()
}

# %%
plot_dist_violin <- function(df_in,ref_in){
    df_in = as.data.frame(as.matrix(df_in))
    
    df_plot=data.frame()
    for (row in rownames(df_in)){
        splits = strsplit(row,"-")
        if(splits[[1]][2]=="expected"){
            next
        }else{
            df_plot[nrow(df_plot)+1,"dist"]=df_in[row,paste(splits[[1]][1],"expected",sep="-")]
            df_plot[nrow(df_plot),"name"]=splits[[1]][2]
        }
    }

    p = ggplot(df_plot, aes(x=name, y=dist, color=name)) + 
            geom_violin(trim=FALSE) + 
            labs(color = df_plot$name) +
            theme(axis.text.x = element_text(angle = 90, hjust = 1),
                  axis.title.x = element_blank(), 
                 legend.position = "none") + 
            xlab("Benchmark ID") +
            ylab("Bray-Curtis Dissimilarity") +
            stat_summary(fun.data=mean_sdl, color="red")
    
    
    fig = ggarrange(p, 
              #labels = c("A"),
              #top = as.character(title_in),
              #common.legend = TRUE#,
              ncol = 1, nrow = 1)
    annotate_figure(fig, top = text_grob("Bray-Curtis Dissimilarity", color = "blue", face = "bold", size = 14)
    )
    ggsave(paste(out_dir,"/img/violin_bc_summary_allgroups_",ref_in,".jpg",sep=""))
    return(df_plot)

}

# %% [markdown]
# <h2> Statistics <h2>

# %%
tstat_paired_f1 <- function(f1_in,subgroup_in){
    
    df_out = data.frame()
    
    cal_list = c("TAR","TDR","F1")
    
    for (cal in cal_list){
    
        comb_list = combn(unique(f1_in[,subgroup_in]),2)
        count=1
        
        for (i in 1:(length(comb_list)/2)){
            
            tstatdf=data.frame()
            var1 = as.character(comb_list[count])
            var2 = as.character(comb_list[count+1])
            count=count+2

            df = f1_in %>%
                filter(f1_in[,subgroup_in] == var1 | f1_in[,subgroup_in] == var2) %>%
                select(subgroup_in, cal)
            
            tmp = t.test(get(cal) ~ get(subgroup_in), data = df)
            tstatdf[nrow(tstatdf)+1,"level"] = cal
            tstatdf[nrow(tstatdf),"comparison"] = paste(var1,var2,sep="_")
            tstatdf[nrow(tstatdf),"pval"] = tmp$p.value
            if(tmp$p.value<0.05){
                tstatdf[nrow(tstatdf),"sig"] = "sig"
            } else{
                tstatdf[nrow(tstatdf),"sig"] = "ns"
            }
            

            df_out = bind_rows(df_out,tstatdf)
        }
    }
        
    return(df_out)
}

# %%
adonis_bc <- function(df_in){
    
    for(i in 1:nrow(df_in)){
        split = strsplit(df_in[i,"name"],"_")
        df_in[i,"tax.ref"]=split[[1]][length(split[[1]])] #add col for ref db
        
        if(length(split[[1]])==4){ #dada or dn do not have add' tax ref so they are then 2, otherwise 3
            df_in[i,"tax.type"]=split[[1]][3]
        } else{
            df_in[i,"tax.type"]=split[[1]][2]
        }
        
        df_in[i,"group.type"]=split[[1]][1]  
    }

    cal_list = c("tax.ref","tax.type","group.type")
    df_out=data.frame()
    
    for (cal in cal_list){
        st = adonis(df_in[,1] ~ df_in[,cal],
                    data=df_in, permutations = 99, method="bray")
        df_out[nrow(df_out)+1,"level"] = cal
        df_out[nrow(df_out),"comparison"] = "bray-curtis"
        df_out[nrow(df_out),"pval"] = as.numeric(st$aov.tab$"Pr(>F)"[1])
        
        if(df_out[nrow(df_out),"pval"]<0.05){
            df_out[nrow(df_out),"sig"] = "sig"
        } else{
            df_out[nrow(df_out),"sig"] = "ns"
        }   
    }
    
    dist_s = vegdist(subset(dissdf_s,select = -c(bmark,db,Group.1)),na.rm=TRUE)
    dist_g = vegdist(subset(dissdf_g,select = -c(bmark,db,Group.1)),na.rm=TRUE)
    
    df_out[nrow(df_out)+1,"homo_s"] = anova(betadisper(dist_s,dissdf_s$bmark))$"Pr(>F)"[1]
    df_out[nrow(df_out)+1,"homo_g"] = anova(betadisper(dist_g,dissdf_g$bmark))$"Pr(>F)"[1]
    
    return(df_out)
}

# %% [markdown]
# <h2> Run Production Code <h2>

# %%
#Create a merged dfs for all variables
mergedf_f1stats = data.frame()
EOdf_stats_merged = data.frame()
dissdf_s = data.frame()
dissdf_g = data.frame()

# %%
#List of all variables to test
test_list = unique(benchmarkdf$x)
#test_list = test_list[1]
#test_list

# %%
for (variable in test_list){
    print("\n****************************************************************************")
    print(paste("Analysis for ",variable))
    
    #Create the phyloseq object
    tax_file = paste(out_dir,'taxonomic_classification/',variable,sep="")
    table_file = paste(out_dir,'taxonomic_classification/',benchmarkdf[variable,"table.file"],sep="")
    phy_obj = phylo_create(tax_file,table_file)  
    
    #Create glomed, subsetted obj
    seq_obj = phy_seq(phy_obj)
    remove(phy_obj)
    
    #Create OTUdf
    OTUdf = otu_extract(seq_obj)
    
    #Create TAXdf
    TAXdf = tax_extract(seq_obj)
    
    #Clean df's
    OTUdf_clean = otu_tax_clean(OTUdf,TAXdf)
    
    #Create TP,FP,FN df
    tax_ref = as.character(benchmarkdf[variable,"tax.ref"])
    if(tax_ref=='silva'){
        CONTdf_use = CONTdf_s
        F1df = bench_compare(OTUdf_clean, CONTdf_use)
    } else{
        CONTdf_use = CONTdf_g
        F1df = bench_compare(OTUdf_clean, CONTdf_use)
    }
    
    #Create TP,FP,FN counts    
    if(benchmarkdf[variable,"group.type"]=="dada" | benchmarkdf[variable,"group.type"]=="dn"){
        bench_key = paste(benchmarkdf[variable,"group.type"],benchmarkdf[variable,"tax.type"],
                         benchmarkdf[variable,"tax.ref"],sep="_")
    } else{
        bench_key = paste(benchmarkdf[variable,"group.type"],benchmarkdf[variable,"group.ref"],
                         benchmarkdf[variable,"tax.type"],benchmarkdf[variable,"tax.ref"],sep="_")
    }         
    F1df_counts = bench_counts(OTUdf_clean,F1df,bench_key,variable)
    temp = F1df_counts
    temp$sample_name = rownames(temp)
    mergedf_f1stats = rbind(mergedf_f1stats,temp)
    
    #Create violin plots for each control - counts
    x_list = c("FN","TP","FP")
    y_labs = c("False negative","True positive", "False positive")
    plot_f1_violin(F1df_counts,x_list,y_labs,"Subject.ID",bench_key,"counts")
    
    #Create violin plots for each control - summary
    x_list = c("TAR","TDR","F1")
    y_labs = c("Taxonmic Accuracy Rate","Taxonmic Detection Rate", "F-Measure")
    plot_f1_violin(F1df_counts,x_list,y_labs,"Subject.ID",bench_key,"summary")

    #calculate relative abundance
    RAdf = cal_relabun(OTUdf_clean)
    RAdf$Sample_name = rownames(RAdf)
    
    #Create scatter plots
    #Determine expected to observed scatter plots, normality, spearman coeff 
    title = paste("Scatterplots of controls: ", variable,sep="")
    EOdf_stats = cal_EO(RAdf,CONTdf_use,variable,title)    
    EOdf_stats_merged = rbind(EOdf_stats_merged,EOdf_stats)   
    
    #Create averaged OTU df
    dissdf = create_av_RAdf(RAdf,bench_key,variable)
    if(benchmarkdf[variable,"tax.ref"]=="silva"){
        dissdf_s = bind_rows(dissdf_s,dissdf)
    } else{
        dissdf_g = bind_rows(dissdf_g,dissdf)
    }
    
    #save files
    #write.csv(OTUdf_clean,paste(out_dir,"bench_files/OTUcounts_",bench_key,".csv",sep=""))
    #write.csv(F1df,paste(out_dir,"/bench_files/F1counts_",bench_key,".csv",sep=""))
    write.csv(F1df_counts,paste(out_dir,"bench_files/F1stats_",bench_key,".csv",sep=""))
}
# Out:
# [1] "\n****************************************************************************"
# [1] "Analysis for  blast_cl_gg_gg.qza"
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 910 taxa and 351 samples ]
# sample_data() Sample Data:       [ 351 samples by 24 sample variables ]
# tax_table()   Taxonomy Table:    [ 910 taxa by 7 taxonomic ranks ]
# Warning message in as_grob.default(plot):
# "Cannot convert object of class character into a grob."
# Saving 6.67 x 6.67 in image
#
# Warning message in as_grob.default(plot):
# "Cannot convert object of class character into a grob."
# Saving 6.67 x 6.67 in image
#    Sample_name                                            taxa.id Subject.ID
# 1     SC284730                          f__Bacillaceaeg__Bacillus    MSA1000
# 2     SC555341                          f__Bacillaceaeg__Bacillus    MSA1000
# 3     SC555347                          f__Bacillaceaeg__Bacillus    MSA1000
# 4     SC326763                          f__Bacillaceaeg__Bacillus    MSA1000
# 5     SC284724                          f__Bacillaceaeg__Bacillus    MSA1000
# 6     SC284730            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1000
# 7     SC555341            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1000
# 8     SC555347            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1000
# 9     SC326763            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1000
# 10    SC284724            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1000
# 11    SC284730 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1000
# 12    SC555341 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1000
# 13    SC555347 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1000
# 14    SC326763 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1000
# 15    SC284724 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1000
# 16    SC284730                    f__Deinococcaceaeg__Deinococcus    MSA1000
# 17    SC555341                    f__Deinococcaceaeg__Deinococcus    MSA1000
# 18    SC555347                    f__Deinococcaceaeg__Deinococcus    MSA1000
# 19    SC326763                    f__Deinococcaceaeg__Deinococcus    MSA1000
# 20    SC284724                    f__Deinococcaceaeg__Deinococcus    MSA1000
# 21    SC284730       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1000
# 22    SC555341       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1000
# 23    SC555347       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1000
# 24    SC326763       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1000
# 25    SC284724       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1000
# 26    SC284730                  f__Enterococcaceaeg__Enterococcus    MSA1000
# 27    SC555341                  f__Enterococcaceaeg__Enterococcus    MSA1000
# 28    SC555347                  f__Enterococcaceaeg__Enterococcus    MSA1000
# 29    SC326763                  f__Enterococcaceaeg__Enterococcus    MSA1000
# 30    SC284724                  f__Enterococcaceaeg__Enterococcus    MSA1000
# 31    SC284730                f__Lactobacillaceaeg__Lactobacillus    MSA1000
# 32    SC555341                f__Lactobacillaceaeg__Lactobacillus    MSA1000
# 33    SC555347                f__Lactobacillaceaeg__Lactobacillus    MSA1000
# 34    SC326763                f__Lactobacillaceaeg__Lactobacillus    MSA1000
# 35    SC284724                f__Lactobacillaceaeg__Lactobacillus    MSA1000
# 36    SC284730                  f__Rhodobacteraceaeg__Rhodobacter    MSA1000
# 37    SC555341                  f__Rhodobacteraceaeg__Rhodobacter    MSA1000
# 38    SC555347                  f__Rhodobacteraceaeg__Rhodobacter    MSA1000
# 39    SC326763                  f__Rhodobacteraceaeg__Rhodobacter    MSA1000
# 40    SC284724                  f__Rhodobacteraceaeg__Rhodobacter    MSA1000
# 41    SC284730              f__Staphylococcaceaeg__Staphylococcus    MSA1000
# 42    SC555341              f__Staphylococcaceaeg__Staphylococcus    MSA1000
# 43    SC555347              f__Staphylococcaceaeg__Staphylococcus    MSA1000
# 44    SC326763              f__Staphylococcaceaeg__Staphylococcus    MSA1000
# 45    SC284724              f__Staphylococcaceaeg__Staphylococcus    MSA1000
# 46    SC284730                f__Streptococcaceaeg__Streptococcus    MSA1000
# 47    SC555341                f__Streptococcaceaeg__Streptococcus    MSA1000
# 48    SC555347                f__Streptococcaceaeg__Streptococcus    MSA1000
# 49    SC326763                f__Streptococcaceaeg__Streptococcus    MSA1000
# 50    SC284724                f__Streptococcaceaeg__Streptococcus    MSA1000
#    exp              bench         obs
# 1  0.1 blast_cl_gg_gg.qza 0.345916238
# 2  0.1 blast_cl_gg_gg.qza 0.245243841
# 3  0.1 blast_cl_gg_gg.qza 0.211361022
# 4  0.1 blast_cl_gg_gg.qza 0.000000000
# 5  0.1 blast_cl_gg_gg.qza 0.384197720
# 6  0.1 blast_cl_gg_gg.qza 0.060784056
# 7  0.1 blast_cl_gg_gg.qza 0.071244178
# 8  0.1 blast_cl_gg_gg.qza 0.142783720
# 9  0.1 blast_cl_gg_gg.qza 0.000000000
# 10 0.1 blast_cl_gg_gg.qza 0.052383836
# 11 0.1 blast_cl_gg_gg.qza 0.000000000
# 12 0.1 blast_cl_gg_gg.qza 0.000000000
# 13 0.1 blast_cl_gg_gg.qza 0.000000000
# 14 0.1 blast_cl_gg_gg.qza 0.000000000
# 15 0.1 blast_cl_gg_gg.qza 0.000000000
# 16 0.1 blast_cl_gg_gg.qza 0.016676799
# 17 0.1 blast_cl_gg_gg.qza 0.018772097
# 18 0.1 blast_cl_gg_gg.qza 0.033015982
# 19 0.1 blast_cl_gg_gg.qza 0.000000000
# 20 0.1 blast_cl_gg_gg.qza 0.019816603
# 21 0.1 blast_cl_gg_gg.qza 0.000000000
# 22 0.1 blast_cl_gg_gg.qza 0.000000000
# 23 0.1 blast_cl_gg_gg.qza 0.000000000
# 24 0.1 blast_cl_gg_gg.qza 0.000000000
# 25 0.1 blast_cl_gg_gg.qza 0.000000000
# 26 0.1 blast_cl_gg_gg.qza 0.035777073
# 27 0.1 blast_cl_gg_gg.qza 0.039396150
# 28 0.1 blast_cl_gg_gg.qza 0.044592379
# 29 0.1 blast_cl_gg_gg.qza 0.000000000
# 30 0.1 blast_cl_gg_gg.qza 0.039208186
# 31 0.1 blast_cl_gg_gg.qza 0.054918423
# 32 0.1 blast_cl_gg_gg.qza 0.040294068
# 33 0.1 blast_cl_gg_gg.qza 0.042267310
# 34 0.1 blast_cl_gg_gg.qza 0.000000000
# 35 0.1 blast_cl_gg_gg.qza 0.045721633
# 36 0.1 blast_cl_gg_gg.qza 0.005471304
# 37 0.1 blast_cl_gg_gg.qza 0.023430047
# 38 0.1 blast_cl_gg_gg.qza 0.030593015
# 39 0.1 blast_cl_gg_gg.qza 0.000000000
# 40 0.1 blast_cl_gg_gg.qza 0.005142754
# 41 0.1 blast_cl_gg_gg.qza 0.074413026
# 42 0.1 blast_cl_gg_gg.qza 0.063275156
# 43 0.1 blast_cl_gg_gg.qza 0.059007807
# 44 0.1 blast_cl_gg_gg.qza 1.000000000
# 45 0.1 blast_cl_gg_gg.qza 0.078214487
# 46 0.1 blast_cl_gg_gg.qza 0.101810624
# 47 0.1 blast_cl_gg_gg.qza 0.058897806
# 48 0.1 blast_cl_gg_gg.qza 0.055875083
# 49 0.1 blast_cl_gg_gg.qza 0.000000000
# 50 0.1 blast_cl_gg_gg.qza 0.050290608
# Warning message in cor(rank(x), rank(y)):
# "the standard deviation is zero"
# Warning message in cor(rank(x), rank(y)):
# "the standard deviation is zero"
#    Sample_name                                            taxa.id Subject.ID
# 1     SC284731                          f__Bacillaceaeg__Bacillus    MSA1001
# 2     SC555339                          f__Bacillaceaeg__Bacillus    MSA1001
# 3     SC555349                          f__Bacillaceaeg__Bacillus    MSA1001
# 4     SC326764                          f__Bacillaceaeg__Bacillus    MSA1001
# 5     SC284725                          f__Bacillaceaeg__Bacillus    MSA1001
# 6     SC284731            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1001
# 7     SC555339            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1001
# 8     SC555349            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1001
# 9     SC326764            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1001
# 10    SC284725            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1001
# 11    SC284731 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1001
# 12    SC555339 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1001
# 13    SC555349 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1001
# 14    SC326764 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1001
# 15    SC284725 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1001
# 16    SC284731                    f__Deinococcaceaeg__Deinococcus    MSA1001
# 17    SC555339                    f__Deinococcaceaeg__Deinococcus    MSA1001
# 18    SC555349                    f__Deinococcaceaeg__Deinococcus    MSA1001
# 19    SC326764                    f__Deinococcaceaeg__Deinococcus    MSA1001
# 20    SC284725                    f__Deinococcaceaeg__Deinococcus    MSA1001
# 21    SC284731       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1001
# 22    SC555339       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1001
# 23    SC555349       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1001
# 24    SC326764       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1001
# 25    SC284725       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1001
# 26    SC284731                  f__Enterococcaceaeg__Enterococcus    MSA1001
# 27    SC555339                  f__Enterococcaceaeg__Enterococcus    MSA1001
# 28    SC555349                  f__Enterococcaceaeg__Enterococcus    MSA1001
# 29    SC326764                  f__Enterococcaceaeg__Enterococcus    MSA1001
# 30    SC284725                  f__Enterococcaceaeg__Enterococcus    MSA1001
# 31    SC284731                f__Lactobacillaceaeg__Lactobacillus    MSA1001
# 32    SC555339                f__Lactobacillaceaeg__Lactobacillus    MSA1001
# 33    SC555349                f__Lactobacillaceaeg__Lactobacillus    MSA1001
# 34    SC326764                f__Lactobacillaceaeg__Lactobacillus    MSA1001
# 35    SC284725                f__Lactobacillaceaeg__Lactobacillus    MSA1001
# 36    SC284731                  f__Rhodobacteraceaeg__Rhodobacter    MSA1001
# 37    SC555339                  f__Rhodobacteraceaeg__Rhodobacter    MSA1001
# 38    SC555349                  f__Rhodobacteraceaeg__Rhodobacter    MSA1001
# 39    SC326764                  f__Rhodobacteraceaeg__Rhodobacter    MSA1001
# 40    SC284725                  f__Rhodobacteraceaeg__Rhodobacter    MSA1001
# 41    SC284731              f__Staphylococcaceaeg__Staphylococcus    MSA1001
# 42    SC555339              f__Staphylococcaceaeg__Staphylococcus    MSA1001
# 43    SC555349              f__Staphylococcaceaeg__Staphylococcus    MSA1001
# 44    SC326764              f__Staphylococcaceaeg__Staphylococcus    MSA1001
# 45    SC284725              f__Staphylococcaceaeg__Staphylococcus    MSA1001
# 46    SC284731                f__Streptococcaceaeg__Streptococcus    MSA1001
# 47    SC555339                f__Streptococcaceaeg__Streptococcus    MSA1001
# 48    SC555349                f__Streptococcaceaeg__Streptococcus    MSA1001
# 49    SC326764                f__Streptococcaceaeg__Streptococcus    MSA1001
# 50    SC284725                f__Streptococcaceaeg__Streptococcus    MSA1001
#       exp              bench          obs
# 1  0.0448 blast_cl_gg_gg.qza 0.2561129803
# 2  0.0448 blast_cl_gg_gg.qza 0.2224243649
# 3  0.0448 blast_cl_gg_gg.qza 0.2523640184
# 4  0.0448 blast_cl_gg_gg.qza 0.2572434259
# 5  0.0448 blast_cl_gg_gg.qza 0.2651198687
# 6  0.0004 blast_cl_gg_gg.qza 0.0008250648
# 7  0.0004 blast_cl_gg_gg.qza 0.0010444040
# 8  0.0004 blast_cl_gg_gg.qza 0.0008486220
# 9  0.0004 blast_cl_gg_gg.qza 0.0007021091
# 10 0.0004 blast_cl_gg_gg.qza 0.0005635114
# 11 0.0045 blast_cl_gg_gg.qza 0.0000000000
# 12 0.0045 blast_cl_gg_gg.qza 0.0000000000
# 13 0.0045 blast_cl_gg_gg.qza 0.0000000000
# 14 0.0045 blast_cl_gg_gg.qza 0.0000000000
# 15 0.0045 blast_cl_gg_gg.qza 0.0000000000
# 16 0.0004 blast_cl_gg_gg.qza 0.0001285815
# 17 0.0004 blast_cl_gg_gg.qza 0.0002358332
# 18 0.0004 blast_cl_gg_gg.qza 0.0001212317
# 19 0.0004 blast_cl_gg_gg.qza 0.0001216989
# 20 0.0004 blast_cl_gg_gg.qza 0.0001715035
# 21 0.0448 blast_cl_gg_gg.qza 0.0000000000
# 22 0.0448 blast_cl_gg_gg.qza 0.0000000000
# 23 0.0448 blast_cl_gg_gg.qza 0.0000000000
# 24 0.0448 blast_cl_gg_gg.qza 0.0000000000
# 25 0.0448 blast_cl_gg_gg.qza 0.0000000000
# 26 0.0004 blast_cl_gg_gg.qza 0.0006107623
# 27 0.0004 blast_cl_gg_gg.qza 0.0004716663
# 28 0.0004 blast_cl_gg_gg.qza 0.0006667744
# 29 0.0004 blast_cl_gg_gg.qza 0.0005242415
# 30 0.0004 blast_cl_gg_gg.qza 0.0004532592
# 31 0.0045 blast_cl_gg_gg.qza 0.0074041532
# 32 0.0045 blast_cl_gg_gg.qza 0.0067380904
# 33 0.0045 blast_cl_gg_gg.qza 0.0070920553
# 34 0.0045 blast_cl_gg_gg.qza 0.0060381386
# 35 0.0045 blast_cl_gg_gg.qza 0.0055493624
# 36 0.4478 blast_cl_gg_gg.qza 0.0656194415
# 37 0.4478 blast_cl_gg_gg.qza 0.0813287514
# 38 0.4478 blast_cl_gg_gg.qza 0.0665562111
# 39 0.4478 blast_cl_gg_gg.qza 0.0628996171
# 40 0.4478 blast_cl_gg_gg.qza 0.0675356176
# 41 0.4478 blast_cl_gg_gg.qza 0.5494610291
# 42 0.4478 blast_cl_gg_gg.qza 0.5628663837
# 43 0.4478 blast_cl_gg_gg.qza 0.5706982947
# 44 0.4478 blast_cl_gg_gg.qza 0.5546943017
# 45 0.4478 blast_cl_gg_gg.qza 0.5474023349
# 46 0.0045 blast_cl_gg_gg.qza 0.0074041532
# 47 0.0045 blast_cl_gg_gg.qza 0.0073782090
# 48 0.0045 blast_cl_gg_gg.qza 0.0068091813
# 49 0.0045 blast_cl_gg_gg.qza 0.0075078870
# 50 0.0045 blast_cl_gg_gg.qza 0.0062231260
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
#    Sample_name                                            taxa.id Subject.ID
# 1     SC284732                     f__Actinomycetaceaeg__Schaalia    MSA1002
# 2     SC555342                     f__Actinomycetaceaeg__Schaalia    MSA1002
# 3     SC555346                     f__Actinomycetaceaeg__Schaalia    MSA1002
# 4     SC326765                     f__Actinomycetaceaeg__Schaalia    MSA1002
# 5     SC284726                     f__Actinomycetaceaeg__Schaalia    MSA1002
# 6     SC284732                          f__Bacillaceaeg__Bacillus    MSA1002
# 7     SC555342                          f__Bacillaceaeg__Bacillus    MSA1002
# 8     SC555346                          f__Bacillaceaeg__Bacillus    MSA1002
# 9     SC326765                          f__Bacillaceaeg__Bacillus    MSA1002
# 10    SC284726                          f__Bacillaceaeg__Bacillus    MSA1002
# 11    SC284732                    f__Bacteroidaceaeg__Bacteroides    MSA1002
# 12    SC555342                    f__Bacteroidaceaeg__Bacteroides    MSA1002
# 13    SC555346                    f__Bacteroidaceaeg__Bacteroides    MSA1002
# 14    SC326765                    f__Bacteroidaceaeg__Bacteroides    MSA1002
# 15    SC284726                    f__Bacteroidaceaeg__Bacteroides    MSA1002
# 16    SC284732            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1002
# 17    SC555342            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1002
# 18    SC555346            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1002
# 19    SC326765            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1002
# 20    SC284726            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1002
# 21    SC284732 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1002
# 22    SC555342 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1002
# 23    SC555346 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1002
# 24    SC326765 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1002
# 25    SC284726 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1002
# 26    SC284732                    f__Deinococcaceaeg__Deinococcus    MSA1002
# 27    SC555342                    f__Deinococcaceaeg__Deinococcus    MSA1002
# 28    SC555346                    f__Deinococcaceaeg__Deinococcus    MSA1002
# 29    SC326765                    f__Deinococcaceaeg__Deinococcus    MSA1002
# 30    SC284726                    f__Deinococcaceaeg__Deinococcus    MSA1002
# 31    SC284732       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1002
# 32    SC555342       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1002
# 33    SC555346       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1002
# 34    SC326765       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1002
# 35    SC284726       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1002
# 36    SC284732                  f__Enterococcaceaeg__Enterococcus    MSA1002
# 37    SC555342                  f__Enterococcaceaeg__Enterococcus    MSA1002
# 38    SC555346                  f__Enterococcaceaeg__Enterococcus    MSA1002
# 39    SC326765                  f__Enterococcaceaeg__Enterococcus    MSA1002
# 40    SC284726                  f__Enterococcaceaeg__Enterococcus    MSA1002
# 41    SC284732                f__Helicobacteraceaeg__Helicobacter    MSA1002
# 42    SC555342                f__Helicobacteraceaeg__Helicobacter    MSA1002
# 43    SC555346                f__Helicobacteraceaeg__Helicobacter    MSA1002
# 44    SC326765                f__Helicobacteraceaeg__Helicobacter    MSA1002
# 45    SC284726                f__Helicobacteraceaeg__Helicobacter    MSA1002
# 46    SC284732                f__Lactobacillaceaeg__Lactobacillus    MSA1002
# 47    SC555342                f__Lactobacillaceaeg__Lactobacillus    MSA1002
# 48    SC555346                f__Lactobacillaceaeg__Lactobacillus    MSA1002
# 49    SC326765                f__Lactobacillaceaeg__Lactobacillus    MSA1002
# 50    SC284726                f__Lactobacillaceaeg__Lactobacillus    MSA1002
# 51    SC284732                   f__Moraxellaceaeg__Acinetobacter    MSA1002
# 52    SC555342                   f__Moraxellaceaeg__Acinetobacter    MSA1002
# 53    SC555346                   f__Moraxellaceaeg__Acinetobacter    MSA1002
# 54    SC326765                   f__Moraxellaceaeg__Acinetobacter    MSA1002
# 55    SC284726                   f__Moraxellaceaeg__Acinetobacter    MSA1002
# 56    SC284732                       f__Neisseriaceaeg__Neisseria    MSA1002
# 57    SC555342                       f__Neisseriaceaeg__Neisseria    MSA1002
# 58    SC555346                       f__Neisseriaceaeg__Neisseria    MSA1002
# 59    SC326765                       f__Neisseriaceaeg__Neisseria    MSA1002
# 60    SC284726                       f__Neisseriaceaeg__Neisseria    MSA1002
# 61    SC284732              f__Porphyromonadaceaeg__Porphyromonas    MSA1002
# 62    SC555342              f__Porphyromonadaceaeg__Porphyromonas    MSA1002
# 63    SC555346              f__Porphyromonadaceaeg__Porphyromonas    MSA1002
# 64    SC326765              f__Porphyromonadaceaeg__Porphyromonas    MSA1002
# 65    SC284726              f__Porphyromonadaceaeg__Porphyromonas    MSA1002
# 66    SC284732            f__Propionibacteriaceaeg__Cutibacterium    MSA1002
# 67    SC555342            f__Propionibacteriaceaeg__Cutibacterium    MSA1002
# 68    SC555346            f__Propionibacteriaceaeg__Cutibacterium    MSA1002
# 69    SC326765            f__Propionibacteriaceaeg__Cutibacterium    MSA1002
# 70    SC284726            f__Propionibacteriaceaeg__Cutibacterium    MSA1002
# 71    SC284732                  f__Pseudomonadaceaeg__Pseudomonas    MSA1002
# 72    SC555342                  f__Pseudomonadaceaeg__Pseudomonas    MSA1002
# 73    SC555346                  f__Pseudomonadaceaeg__Pseudomonas    MSA1002
# 74    SC326765                  f__Pseudomonadaceaeg__Pseudomonas    MSA1002
# 75    SC284726                  f__Pseudomonadaceaeg__Pseudomonas    MSA1002
# 76    SC284732                  f__Rhodobacteraceaeg__Rhodobacter    MSA1002
# 77    SC555342                  f__Rhodobacteraceaeg__Rhodobacter    MSA1002
# 78    SC555346                  f__Rhodobacteraceaeg__Rhodobacter    MSA1002
# 79    SC326765                  f__Rhodobacteraceaeg__Rhodobacter    MSA1002
# 80    SC284726                  f__Rhodobacteraceaeg__Rhodobacter    MSA1002
# 81    SC284732              f__Staphylococcaceaeg__Staphylococcus    MSA1002
# 82    SC555342              f__Staphylococcaceaeg__Staphylococcus    MSA1002
# 83    SC555346              f__Staphylococcaceaeg__Staphylococcus    MSA1002
# 84    SC326765              f__Staphylococcaceaeg__Staphylococcus    MSA1002
# 85    SC284726              f__Staphylococcaceaeg__Staphylococcus    MSA1002
# 86    SC284732                f__Streptococcaceaeg__Streptococcus    MSA1002
# 87    SC555342                f__Streptococcaceaeg__Streptococcus    MSA1002
# 88    SC555346                f__Streptococcaceaeg__Streptococcus    MSA1002
# 89    SC326765                f__Streptococcaceaeg__Streptococcus    MSA1002
# 90    SC284726                f__Streptococcaceaeg__Streptococcus    MSA1002
#     exp              bench         obs
# 1  0.05 blast_cl_gg_gg.qza 0.000000000
# 2  0.05 blast_cl_gg_gg.qza 0.000000000
# 3  0.05 blast_cl_gg_gg.qza 0.000000000
# 4  0.05 blast_cl_gg_gg.qza 0.000000000
# 5  0.05 blast_cl_gg_gg.qza 0.000000000
# 6  0.05 blast_cl_gg_gg.qza 0.204615563
# 7  0.05 blast_cl_gg_gg.qza 0.165012308
# 8  0.05 blast_cl_gg_gg.qza 0.194144674
# 9  0.05 blast_cl_gg_gg.qza 0.219934102
# 10 0.05 blast_cl_gg_gg.qza 0.222408168
# 11 0.05 blast_cl_gg_gg.qza 0.073176139
# 12 0.05 blast_cl_gg_gg.qza 0.087270706
# 13 0.05 blast_cl_gg_gg.qza 0.078026499
# 14 0.05 blast_cl_gg_gg.qza 0.078003008
# 15 0.05 blast_cl_gg_gg.qza 0.078854857
# 16 0.05 blast_cl_gg_gg.qza 0.034375723
# 17 0.05 blast_cl_gg_gg.qza 0.048955769
# 18 0.05 blast_cl_gg_gg.qza 0.048322470
# 19 0.05 blast_cl_gg_gg.qza 0.034936609
# 20 0.05 blast_cl_gg_gg.qza 0.031691401
# 21 0.05 blast_cl_gg_gg.qza 0.000000000
# 22 0.05 blast_cl_gg_gg.qza 0.000000000
# 23 0.05 blast_cl_gg_gg.qza 0.000000000
# 24 0.05 blast_cl_gg_gg.qza 0.000000000
# 25 0.05 blast_cl_gg_gg.qza 0.000000000
# 26 0.05 blast_cl_gg_gg.qza 0.008945785
# 27 0.05 blast_cl_gg_gg.qza 0.004566029
# 28 0.05 blast_cl_gg_gg.qza 0.007239021
# 29 0.05 blast_cl_gg_gg.qza 0.008228279
# 30 0.05 blast_cl_gg_gg.qza 0.009767393
# 31 0.05 blast_cl_gg_gg.qza 0.000000000
# 32 0.05 blast_cl_gg_gg.qza 0.000000000
# 33 0.05 blast_cl_gg_gg.qza 0.000000000
# 34 0.05 blast_cl_gg_gg.qza 0.000000000
# 35 0.05 blast_cl_gg_gg.qza 0.000000000
# 36 0.05 blast_cl_gg_gg.qza 0.021863191
# 37 0.05 blast_cl_gg_gg.qza 0.019177321
# 38 0.05 blast_cl_gg_gg.qza 0.023987606
# 39 0.05 blast_cl_gg_gg.qza 0.022813552
# 40 0.05 blast_cl_gg_gg.qza 0.025544680
# 41 0.05 blast_cl_gg_gg.qza 0.031387368
# 42 0.05 blast_cl_gg_gg.qza 0.043357421
# 43 0.05 blast_cl_gg_gg.qza 0.036836200
# 44 0.05 blast_cl_gg_gg.qza 0.033736838
# 45 0.05 blast_cl_gg_gg.qza 0.030102095
# 46 0.05 blast_cl_gg_gg.qza 0.039263129
# 47 0.05 blast_cl_gg_gg.qza 0.034344477
# 48 0.05 blast_cl_gg_gg.qza 0.035527300
# 49 0.05 blast_cl_gg_gg.qza 0.032617649
# 50 0.05 blast_cl_gg_gg.qza 0.031038838
# 51 0.05 blast_cl_gg_gg.qza 0.092070255
# 52 0.05 blast_cl_gg_gg.qza 0.084292861
# 53 0.05 blast_cl_gg_gg.qza 0.088711401
# 54 0.05 blast_cl_gg_gg.qza 0.092749445
# 55 0.05 blast_cl_gg_gg.qza 0.095800442
# 56 0.05 blast_cl_gg_gg.qza 0.030693298
# 57 0.05 blast_cl_gg_gg.qza 0.035495910
# 58 0.05 blast_cl_gg_gg.qza 0.033043060
# 59 0.05 blast_cl_gg_gg.qza 0.034560562
# 60 0.05 blast_cl_gg_gg.qza 0.029512683
# 61 0.05 blast_cl_gg_gg.qza 0.033190021
# 62 0.05 blast_cl_gg_gg.qza 0.048519019
# 63 0.05 blast_cl_gg_gg.qza 0.044769740
# 64 0.05 blast_cl_gg_gg.qza 0.029376477
# 65 0.05 blast_cl_gg_gg.qza 0.031123040
# 66 0.05 blast_cl_gg_gg.qza 0.000000000
# 67 0.05 blast_cl_gg_gg.qza 0.000000000
# 68 0.05 blast_cl_gg_gg.qza 0.000000000
# 69 0.05 blast_cl_gg_gg.qza 0.000000000
# 70 0.05 blast_cl_gg_gg.qza 0.000000000
# 71 0.05 blast_cl_gg_gg.qza 0.011066554
# 72 0.05 blast_cl_gg_gg.qza 0.008417375
# 73 0.05 blast_cl_gg_gg.qza 0.011245860
# 74 0.05 blast_cl_gg_gg.qza 0.011379915
# 75 0.05 blast_cl_gg_gg.qza 0.012946006
# 76 0.05 blast_cl_gg_gg.qza 0.003720984
# 77 0.05 blast_cl_gg_gg.qza 0.004168983
# 78 0.05 blast_cl_gg_gg.qza 0.004220536
# 79 0.05 blast_cl_gg_gg.qza 0.003697801
# 80 0.05 blast_cl_gg_gg.qza 0.003883802
# 81 0.10 blast_cl_gg_gg.qza 0.098307241
# 82 0.10 blast_cl_gg_gg.qza 0.083022314
# 83 0.10 blast_cl_gg_gg.qza 0.098301101
# 84 0.10 blast_cl_gg_gg.qza 0.104827734
# 85 0.10 blast_cl_gg_gg.qza 0.108546469
# 86 0.10 blast_cl_gg_gg.qza 0.072867664
# 87 0.10 blast_cl_gg_gg.qza 0.070634479
# 88 0.10 blast_cl_gg_gg.qza 0.075836094
# 89 0.10 blast_cl_gg_gg.qza 0.039959530
# 90 0.10 blast_cl_gg_gg.qza 0.039195874
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
#    Sample_name                                            taxa.id Subject.ID
# 1     SC284733                     f__Actinomycetaceaeg__Schaalia    MSA1003
# 2     SC555343                     f__Actinomycetaceaeg__Schaalia    MSA1003
# 3     SC555350                     f__Actinomycetaceaeg__Schaalia    MSA1003
# 4     SC326766                     f__Actinomycetaceaeg__Schaalia    MSA1003
# 5     SC284727                     f__Actinomycetaceaeg__Schaalia    MSA1003
# 6     SC284733                          f__Bacillaceaeg__Bacillus    MSA1003
# 7     SC555343                          f__Bacillaceaeg__Bacillus    MSA1003
# 8     SC555350                          f__Bacillaceaeg__Bacillus    MSA1003
# 9     SC326766                          f__Bacillaceaeg__Bacillus    MSA1003
# 10    SC284727                          f__Bacillaceaeg__Bacillus    MSA1003
# 11    SC284733                    f__Bacteroidaceaeg__Bacteroides    MSA1003
# 12    SC555343                    f__Bacteroidaceaeg__Bacteroides    MSA1003
# 13    SC555350                    f__Bacteroidaceaeg__Bacteroides    MSA1003
# 14    SC326766                    f__Bacteroidaceaeg__Bacteroides    MSA1003
# 15    SC284727                    f__Bacteroidaceaeg__Bacteroides    MSA1003
# 16    SC284733            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1003
# 17    SC555343            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1003
# 18    SC555350            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1003
# 19    SC326766            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1003
# 20    SC284727            f__Bifidobacteriaceaeg__Bifidobacterium    MSA1003
# 21    SC284733 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1003
# 22    SC555343 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1003
# 23    SC555350 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1003
# 24    SC326766 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1003
# 25    SC284727 f__Clostridiaceae.1Dg__Clostridium.sensu.stricto.1    MSA1003
# 26    SC284733                    f__Deinococcaceaeg__Deinococcus    MSA1003
# 27    SC555343                    f__Deinococcaceaeg__Deinococcus    MSA1003
# 28    SC555350                    f__Deinococcaceaeg__Deinococcus    MSA1003
# 29    SC326766                    f__Deinococcaceaeg__Deinococcus    MSA1003
# 30    SC284727                    f__Deinococcaceaeg__Deinococcus    MSA1003
# 31    SC284733       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1003
# 32    SC555343       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1003
# 33    SC555350       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1003
# 34    SC326766       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1003
# 35    SC284727       f__Enterobacteriaceaeg__Escherichia.Shigella    MSA1003
# 36    SC284733                  f__Enterococcaceaeg__Enterococcus    MSA1003
# 37    SC555343                  f__Enterococcaceaeg__Enterococcus    MSA1003
# 38    SC555350                  f__Enterococcaceaeg__Enterococcus    MSA1003
# 39    SC326766                  f__Enterococcaceaeg__Enterococcus    MSA1003
# 40    SC284727                  f__Enterococcaceaeg__Enterococcus    MSA1003
# 41    SC284733                f__Helicobacteraceaeg__Helicobacter    MSA1003
# 42    SC555343                f__Helicobacteraceaeg__Helicobacter    MSA1003
# 43    SC555350                f__Helicobacteraceaeg__Helicobacter    MSA1003
# 44    SC326766                f__Helicobacteraceaeg__Helicobacter    MSA1003
# 45    SC284727                f__Helicobacteraceaeg__Helicobacter    MSA1003
# 46    SC284733                f__Lactobacillaceaeg__Lactobacillus    MSA1003
# 47    SC555343                f__Lactobacillaceaeg__Lactobacillus    MSA1003
# 48    SC555350                f__Lactobacillaceaeg__Lactobacillus    MSA1003
# 49    SC326766                f__Lactobacillaceaeg__Lactobacillus    MSA1003
# 50    SC284727                f__Lactobacillaceaeg__Lactobacillus    MSA1003
# 51    SC284733                   f__Moraxellaceaeg__Acinetobacter    MSA1003
# 52    SC555343                   f__Moraxellaceaeg__Acinetobacter    MSA1003
# 53    SC555350                   f__Moraxellaceaeg__Acinetobacter    MSA1003
# 54    SC326766                   f__Moraxellaceaeg__Acinetobacter    MSA1003
# 55    SC284727                   f__Moraxellaceaeg__Acinetobacter    MSA1003
# 56    SC284733                       f__Neisseriaceaeg__Neisseria    MSA1003
# 57    SC555343                       f__Neisseriaceaeg__Neisseria    MSA1003
# 58    SC555350                       f__Neisseriaceaeg__Neisseria    MSA1003
# 59    SC326766                       f__Neisseriaceaeg__Neisseria    MSA1003
# 60    SC284727                       f__Neisseriaceaeg__Neisseria    MSA1003
# 61    SC284733              f__Porphyromonadaceaeg__Porphyromonas    MSA1003
# 62    SC555343              f__Porphyromonadaceaeg__Porphyromonas    MSA1003
# 63    SC555350              f__Porphyromonadaceaeg__Porphyromonas    MSA1003
# 64    SC326766              f__Porphyromonadaceaeg__Porphyromonas    MSA1003
# 65    SC284727              f__Porphyromonadaceaeg__Porphyromonas    MSA1003
# 66    SC284733            f__Propionibacteriaceaeg__Cutibacterium    MSA1003
# 67    SC555343            f__Propionibacteriaceaeg__Cutibacterium    MSA1003
# 68    SC555350            f__Propionibacteriaceaeg__Cutibacterium    MSA1003
# 69    SC326766            f__Propionibacteriaceaeg__Cutibacterium    MSA1003
# 70    SC284727            f__Propionibacteriaceaeg__Cutibacterium    MSA1003
# 71    SC284733                  f__Pseudomonadaceaeg__Pseudomonas    MSA1003
# 72    SC555343                  f__Pseudomonadaceaeg__Pseudomonas    MSA1003
# 73    SC555350                  f__Pseudomonadaceaeg__Pseudomonas    MSA1003
# 74    SC326766                  f__Pseudomonadaceaeg__Pseudomonas    MSA1003
# 75    SC284727                  f__Pseudomonadaceaeg__Pseudomonas    MSA1003
# 76    SC284733                  f__Rhodobacteraceaeg__Rhodobacter    MSA1003
# 77    SC555343                  f__Rhodobacteraceaeg__Rhodobacter    MSA1003
# 78    SC555350                  f__Rhodobacteraceaeg__Rhodobacter    MSA1003
# 79    SC326766                  f__Rhodobacteraceaeg__Rhodobacter    MSA1003
# 80    SC284727                  f__Rhodobacteraceaeg__Rhodobacter    MSA1003
# 81    SC284733              f__Staphylococcaceaeg__Staphylococcus    MSA1003
# 82    SC555343              f__Staphylococcaceaeg__Staphylococcus    MSA1003
# 83    SC555350              f__Staphylococcaceaeg__Staphylococcus    MSA1003
# 84    SC326766              f__Staphylococcaceaeg__Staphylococcus    MSA1003
# 85    SC284727              f__Staphylococcaceaeg__Staphylococcus    MSA1003
# 86    SC284733                f__Streptococcaceaeg__Streptococcus    MSA1003
# 87    SC555343                f__Streptococcaceaeg__Streptococcus    MSA1003
# 88    SC555350                f__Streptococcaceaeg__Streptococcus    MSA1003
# 89    SC326766                f__Streptococcaceaeg__Streptococcus    MSA1003
# 90    SC284727                f__Streptococcaceaeg__Streptococcus    MSA1003
#        exp              bench          obs
# 1  0.00002 blast_cl_gg_gg.qza 0.000000e+00
# 2  0.00002 blast_cl_gg_gg.qza 0.000000e+00
# 3  0.00002 blast_cl_gg_gg.qza 0.000000e+00
# 4  0.00002 blast_cl_gg_gg.qza 0.000000e+00
# 5  0.00002 blast_cl_gg_gg.qza 0.000000e+00
# 6  0.01800 blast_cl_gg_gg.qza 8.028835e-02
# 7  0.01800 blast_cl_gg_gg.qza 8.487726e-02
# 8  0.01800 blast_cl_gg_gg.qza 7.395216e-02
# 9  0.01800 blast_cl_gg_gg.qza 9.318682e-02
# 10 0.01800 blast_cl_gg_gg.qza 1.001114e-01
# 11 0.00020 blast_cl_gg_gg.qza 9.058662e-04
# 12 0.00020 blast_cl_gg_gg.qza 4.034385e-04
# 13 0.00020 blast_cl_gg_gg.qza 4.540424e-04
# 14 0.00020 blast_cl_gg_gg.qza 6.177054e-04
# 15 0.00020 blast_cl_gg_gg.qza 4.512063e-04
# 16 0.00020 blast_cl_gg_gg.qza 1.430315e-04
# 17 0.00020 blast_cl_gg_gg.qza 0.000000e+00
# 18 0.00020 blast_cl_gg_gg.qza 0.000000e+00
# 19 0.00020 blast_cl_gg_gg.qza 1.083694e-04
# 20 0.00020 blast_cl_gg_gg.qza 0.000000e+00
# 21 0.01800 blast_cl_gg_gg.qza 0.000000e+00
# 22 0.01800 blast_cl_gg_gg.qza 0.000000e+00
# 23 0.01800 blast_cl_gg_gg.qza 0.000000e+00
# 24 0.01800 blast_cl_gg_gg.qza 0.000000e+00
# 25 0.01800 blast_cl_gg_gg.qza 0.000000e+00
# 26 0.00002 blast_cl_gg_gg.qza 1.907087e-05
# 27 0.00002 blast_cl_gg_gg.qza 0.000000e+00
# 28 0.00002 blast_cl_gg_gg.qza 0.000000e+00
# 29 0.00002 blast_cl_gg_gg.qza 4.334775e-05
# 30 0.00002 blast_cl_gg_gg.qza 2.820039e-05
# 31 0.18000 blast_cl_gg_gg.qza 0.000000e+00
# 32 0.18000 blast_cl_gg_gg.qza 0.000000e+00
# 33 0.18000 blast_cl_gg_gg.qza 0.000000e+00
# 34 0.18000 blast_cl_gg_gg.qza 0.000000e+00
# 35 0.18000 blast_cl_gg_gg.qza 0.000000e+00
# 36 0.00002 blast_cl_gg_gg.qza 3.242047e-04
# 37 0.00002 blast_cl_gg_gg.qza 3.103373e-04
# 38 0.00002 blast_cl_gg_gg.qza 0.000000e+00
# 39 0.00002 blast_cl_gg_gg.qza 5.418468e-04
# 40 0.00002 blast_cl_gg_gg.qza 5.499076e-04
# 41 0.00180 blast_cl_gg_gg.qza 1.096575e-03
# 42 0.00180 blast_cl_gg_gg.qza 1.675822e-03
# 43 0.00180 blast_cl_gg_gg.qza 1.986435e-03
# 44 0.00180 blast_cl_gg_gg.qza 1.202900e-03
# 45 0.00180 blast_cl_gg_gg.qza 1.085715e-03
# 46 0.00180 blast_cl_gg_gg.qza 1.594229e-01
# 47 0.00180 blast_cl_gg_gg.qza 1.205350e-01
# 48 0.00180 blast_cl_gg_gg.qza 1.082891e-01
# 49 0.00180 blast_cl_gg_gg.qza 1.428417e-01
# 50 0.00180 blast_cl_gg_gg.qza 1.414955e-01
# 51 0.00180 blast_cl_gg_gg.qza 3.232512e-03
# 52 0.00180 blast_cl_gg_gg.qza 4.375756e-03
# 53 0.00180 blast_cl_gg_gg.qza 3.717472e-03
# 54 0.00180 blast_cl_gg_gg.qza 3.424472e-03
# 55 0.00180 blast_cl_gg_gg.qza 3.807053e-03
# 56 0.00180 blast_cl_gg_gg.qza 1.029827e-03
# 57 0.00180 blast_cl_gg_gg.qza 1.334451e-03
# 58 0.00180 blast_cl_gg_gg.qza 1.248617e-03
# 59 0.00180 blast_cl_gg_gg.qza 1.192063e-03
# 60 0.00180 blast_cl_gg_gg.qza 1.043415e-03
# 61 0.18000 blast_cl_gg_gg.qza 1.219677e-01
# 62 0.18000 blast_cl_gg_gg.qza 1.494895e-01
# 63 0.18000 blast_cl_gg_gg.qza 1.573541e-01
# 64 0.18000 blast_cl_gg_gg.qza 1.201274e-01
# 65 0.18000 blast_cl_gg_gg.qza 1.139437e-01
# 66 0.00180 blast_cl_gg_gg.qza 0.000000e+00
# 67 0.00180 blast_cl_gg_gg.qza 0.000000e+00
# 68 0.00180 blast_cl_gg_gg.qza 0.000000e+00
# 69 0.00180 blast_cl_gg_gg.qza 0.000000e+00
# 70 0.00180 blast_cl_gg_gg.qza 0.000000e+00
# 71 0.01800 blast_cl_gg_gg.qza 2.889236e-03
# 72 0.01800 blast_cl_gg_gg.qza 4.096453e-03
# 73 0.01800 blast_cl_gg_gg.qza 4.455291e-03
# 74 0.01800 blast_cl_gg_gg.qza 3.489494e-03
# 75 0.01800 blast_cl_gg_gg.qza 3.792953e-03
# 76 0.18000 blast_cl_gg_gg.qza 1.249142e-02
# 77 0.18000 blast_cl_gg_gg.qza 1.526860e-02
# 78 0.18000 blast_cl_gg_gg.qza 1.549420e-02
# 79 0.18000 blast_cl_gg_gg.qza 1.397965e-02
# 80 0.18000 blast_cl_gg_gg.qza 1.425530e-02
# 81 0.19800 blast_cl_gg_gg.qza 2.010642e-01
# 82 0.19800 blast_cl_gg_gg.qza 2.136362e-01
# 83 0.19800 blast_cl_gg_gg.qza 2.109878e-01
# 84 0.19800 blast_cl_gg_gg.qza 2.381525e-01
# 85 0.19800 blast_cl_gg_gg.qza 2.403519e-01
# 86 0.19800 blast_cl_gg_gg.qza 1.397704e-01
# 87 0.19800 blast_cl_gg_gg.qza 1.562238e-01
# 88 0.19800 blast_cl_gg_gg.qza 1.560771e-01
# 89 0.19800 blast_cl_gg_gg.qza 9.960228e-02
# 90 0.19800 blast_cl_gg_gg.qza 1.074717e-01
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
#    Sample_name                                      taxa.id Subject.ID   exp
# 1     SC284734                    f__Bacillaceaeg__Bacillus      D6305 0.174
# 2     SC555340                    f__Bacillaceaeg__Bacillus      D6305 0.174
# 3     SC555348                    f__Bacillaceaeg__Bacillus      D6305 0.174
# 4     SC326767                    f__Bacillaceaeg__Bacillus      D6305 0.174
# 5     SC284728                    f__Bacillaceaeg__Bacillus      D6305 0.174
# 6     SC284734 f__Enterobacteriaceaeg__Escherichia.Shigella      D6305 0.101
# 7     SC555340 f__Enterobacteriaceaeg__Escherichia.Shigella      D6305 0.101
# 8     SC555348 f__Enterobacteriaceaeg__Escherichia.Shigella      D6305 0.101
# 9     SC326767 f__Enterobacteriaceaeg__Escherichia.Shigella      D6305 0.101
# 10    SC284728 f__Enterobacteriaceaeg__Escherichia.Shigella      D6305 0.101
# 11    SC284734           f__Enterobacteriaceaeg__Salmonella      D6305 0.104
# 12    SC555340           f__Enterobacteriaceaeg__Salmonella      D6305 0.104
# 13    SC555348           f__Enterobacteriaceaeg__Salmonella      D6305 0.104
# 14    SC326767           f__Enterobacteriaceaeg__Salmonella      D6305 0.104
# 15    SC284728           f__Enterobacteriaceaeg__Salmonella      D6305 0.104
# 16    SC284734            f__Enterococcaceaeg__Enterococcus      D6305 0.099
# 17    SC555340            f__Enterococcaceaeg__Enterococcus      D6305 0.099
# 18    SC555348            f__Enterococcaceaeg__Enterococcus      D6305 0.099
# 19    SC326767            f__Enterococcaceaeg__Enterococcus      D6305 0.099
# 20    SC284728            f__Enterococcaceaeg__Enterococcus      D6305 0.099
# 21    SC284734          f__Lactobacillaceaeg__Lactobacillus      D6305 0.184
# 22    SC555340          f__Lactobacillaceaeg__Lactobacillus      D6305 0.184
# 23    SC555348          f__Lactobacillaceaeg__Lactobacillus      D6305 0.184
# 24    SC326767          f__Lactobacillaceaeg__Lactobacillus      D6305 0.184
# 25    SC284728          f__Lactobacillaceaeg__Lactobacillus      D6305 0.184
# 26    SC284734                   f__Listeriaceaeg__Listeria      D6305 0.141
# 27    SC555340                   f__Listeriaceaeg__Listeria      D6305 0.141
# 28    SC555348                   f__Listeriaceaeg__Listeria      D6305 0.141
# 29    SC326767                   f__Listeriaceaeg__Listeria      D6305 0.141
# 30    SC284728                   f__Listeriaceaeg__Listeria      D6305 0.141
# 31    SC284734            f__Pseudomonadaceaeg__Pseudomonas      D6305 0.042
# 32    SC555340            f__Pseudomonadaceaeg__Pseudomonas      D6305 0.042
# 33    SC555348            f__Pseudomonadaceaeg__Pseudomonas      D6305 0.042
# 34    SC326767            f__Pseudomonadaceaeg__Pseudomonas      D6305 0.042
# 35    SC284728            f__Pseudomonadaceaeg__Pseudomonas      D6305 0.042
# 36    SC284734        f__Staphylococcaceaeg__Staphylococcus      D6305 0.155
# 37    SC555340        f__Staphylococcaceaeg__Staphylococcus      D6305 0.155
# 38    SC555348        f__Staphylococcaceaeg__Staphylococcus      D6305 0.155
# 39    SC326767        f__Staphylococcaceaeg__Staphylococcus      D6305 0.155
# 40    SC284728        f__Staphylococcaceaeg__Staphylococcus      D6305 0.155
#                 bench        obs
# 1  blast_cl_gg_gg.qza 0.25870454
# 2  blast_cl_gg_gg.qza 0.25611132
# 3  blast_cl_gg_gg.qza 0.29586029
# 4  blast_cl_gg_gg.qza 0.23421726
# 5  blast_cl_gg_gg.qza 0.23303782
# 6  blast_cl_gg_gg.qza 0.00000000
# 7  blast_cl_gg_gg.qza 0.00000000
# 8  blast_cl_gg_gg.qza 0.00000000
# 9  blast_cl_gg_gg.qza 0.00000000
# 10 blast_cl_gg_gg.qza 0.00000000
# 11 blast_cl_gg_gg.qza 0.00000000
# 12 blast_cl_gg_gg.qza 0.00000000
# 13 blast_cl_gg_gg.qza 0.00000000
# 14 blast_cl_gg_gg.qza 0.00000000
# 15 blast_cl_gg_gg.qza 0.00000000
# 16 blast_cl_gg_gg.qza 0.13820981
# 17 blast_cl_gg_gg.qza 0.13759201
# 18 blast_cl_gg_gg.qza 0.11390391
# 19 blast_cl_gg_gg.qza 0.12663329
# 20 blast_cl_gg_gg.qza 0.14600155
# 21 blast_cl_gg_gg.qza 0.08699713
# 22 blast_cl_gg_gg.qza 0.13119862
# 23 blast_cl_gg_gg.qza 0.10655071
# 24 blast_cl_gg_gg.qza 0.09198691
# 25 blast_cl_gg_gg.qza 0.08396123
# 26 blast_cl_gg_gg.qza 0.00000000
# 27 blast_cl_gg_gg.qza 0.00000000
# 28 blast_cl_gg_gg.qza 0.00000000
# 29 blast_cl_gg_gg.qza 0.00000000
# 30 blast_cl_gg_gg.qza 0.00000000
# 31 blast_cl_gg_gg.qza 0.06548137
# 32 blast_cl_gg_gg.qza 0.06371891
# 33 blast_cl_gg_gg.qza 0.07586524
# 34 blast_cl_gg_gg.qza 0.09081781
# 35 blast_cl_gg_gg.qza 0.07072596
# 36 blast_cl_gg_gg.qza 0.31763133
# 37 blast_cl_gg_gg.qza 0.28775587
# 38 blast_cl_gg_gg.qza 0.29370382
# 39 blast_cl_gg_gg.qza 0.34204880
# 40 blast_cl_gg_gg.qza 0.33248215
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
#    Sample_name                                      taxa.id Subject.ID   exp
# 1     SC284735                    f__Bacillaceaeg__Bacillus      D6306 0.174
# 2     SC555344                    f__Bacillaceaeg__Bacillus      D6306 0.174
# 3     SC555345                    f__Bacillaceaeg__Bacillus      D6306 0.174
# 4     SC326768                    f__Bacillaceaeg__Bacillus      D6306 0.174
# 5     SC284729                    f__Bacillaceaeg__Bacillus      D6306 0.174
# 6     SC284735 f__Enterobacteriaceaeg__Escherichia.Shigella      D6306 0.101
# 7     SC555344 f__Enterobacteriaceaeg__Escherichia.Shigella      D6306 0.101
# 8     SC555345 f__Enterobacteriaceaeg__Escherichia.Shigella      D6306 0.101
# 9     SC326768 f__Enterobacteriaceaeg__Escherichia.Shigella      D6306 0.101
# 10    SC284729 f__Enterobacteriaceaeg__Escherichia.Shigella      D6306 0.101
# 11    SC284735           f__Enterobacteriaceaeg__Salmonella      D6306 0.104
# 12    SC555344           f__Enterobacteriaceaeg__Salmonella      D6306 0.104
# 13    SC555345           f__Enterobacteriaceaeg__Salmonella      D6306 0.104
# 14    SC326768           f__Enterobacteriaceaeg__Salmonella      D6306 0.104
# 15    SC284729           f__Enterobacteriaceaeg__Salmonella      D6306 0.104
# 16    SC284735            f__Enterococcaceaeg__Enterococcus      D6306 0.099
# 17    SC555344            f__Enterococcaceaeg__Enterococcus      D6306 0.099
# 18    SC555345            f__Enterococcaceaeg__Enterococcus      D6306 0.099
# 19    SC326768            f__Enterococcaceaeg__Enterococcus      D6306 0.099
# 20    SC284729            f__Enterococcaceaeg__Enterococcus      D6306 0.099
# 21    SC284735          f__Lactobacillaceaeg__Lactobacillus      D6306 0.184
# 22    SC555344          f__Lactobacillaceaeg__Lactobacillus      D6306 0.184
# 23    SC555345          f__Lactobacillaceaeg__Lactobacillus      D6306 0.184
# 24    SC326768          f__Lactobacillaceaeg__Lactobacillus      D6306 0.184
# 25    SC284729          f__Lactobacillaceaeg__Lactobacillus      D6306 0.184
# 26    SC284735                   f__Listeriaceaeg__Listeria      D6306 0.141
# 27    SC555344                   f__Listeriaceaeg__Listeria      D6306 0.141
# 28    SC555345                   f__Listeriaceaeg__Listeria      D6306 0.141
# 29    SC326768                   f__Listeriaceaeg__Listeria      D6306 0.141
# 30    SC284729                   f__Listeriaceaeg__Listeria      D6306 0.141
# 31    SC284735            f__Pseudomonadaceaeg__Pseudomonas      D6306 0.042
# 32    SC555344            f__Pseudomonadaceaeg__Pseudomonas      D6306 0.042
# 33    SC555345            f__Pseudomonadaceaeg__Pseudomonas      D6306 0.042
# 34    SC326768            f__Pseudomonadaceaeg__Pseudomonas      D6306 0.042
# 35    SC284729            f__Pseudomonadaceaeg__Pseudomonas      D6306 0.042
# 36    SC284735        f__Staphylococcaceaeg__Staphylococcus      D6306 0.155
# 37    SC555344        f__Staphylococcaceaeg__Staphylococcus      D6306 0.155
# 38    SC555345        f__Staphylococcaceaeg__Staphylococcus      D6306 0.155
# 39    SC326768        f__Staphylococcaceaeg__Staphylococcus      D6306 0.155
# 40    SC284729        f__Staphylococcaceaeg__Staphylococcus      D6306 0.155
#                 bench        obs
# 1  blast_cl_gg_gg.qza 0.25132275
# 2  blast_cl_gg_gg.qza 0.19508842
# 3  blast_cl_gg_gg.qza 0.23214890
# 4  blast_cl_gg_gg.qza 0.22068268
# 5  blast_cl_gg_gg.qza 0.22404444
# 6  blast_cl_gg_gg.qza 0.00000000
# 7  blast_cl_gg_gg.qza 0.00000000
# 8  blast_cl_gg_gg.qza 0.00000000
# 9  blast_cl_gg_gg.qza 0.00000000
# 10 blast_cl_gg_gg.qza 0.00000000
# 11 blast_cl_gg_gg.qza 0.00000000
# 12 blast_cl_gg_gg.qza 0.00000000
# 13 blast_cl_gg_gg.qza 0.00000000
# 14 blast_cl_gg_gg.qza 0.00000000
# 15 blast_cl_gg_gg.qza 0.00000000
# 16 blast_cl_gg_gg.qza 0.14934240
# 17 blast_cl_gg_gg.qza 0.12416441
# 18 blast_cl_gg_gg.qza 0.13688663
# 19 blast_cl_gg_gg.qza 0.14857336
# 20 blast_cl_gg_gg.qza 0.15872895
# 21 blast_cl_gg_gg.qza 0.11759637
# 22 blast_cl_gg_gg.qza 0.14587778
# 23 blast_cl_gg_gg.qza 0.17110829
# 24 blast_cl_gg_gg.qza 0.13133046
# 25 blast_cl_gg_gg.qza 0.12617549
# 26 blast_cl_gg_gg.qza 0.00000000
# 27 blast_cl_gg_gg.qza 0.00000000
# 28 blast_cl_gg_gg.qza 0.00000000
# 29 blast_cl_gg_gg.qza 0.00000000
# 30 blast_cl_gg_gg.qza 0.00000000
# 31 blast_cl_gg_gg.qza 0.07900227
# 32 blast_cl_gg_gg.qza 0.08168587
# 33 blast_cl_gg_gg.qza 0.07719966
# 34 blast_cl_gg_gg.qza 0.08401513
# 35 blast_cl_gg_gg.qza 0.07991430
# 36 blast_cl_gg_gg.qza 0.30338624
# 37 blast_cl_gg_gg.qza 0.33357038
# 38 blast_cl_gg_gg.qza 0.28168359
# 39 blast_cl_gg_gg.qza 0.31985866
# 40 blast_cl_gg_gg.qza 0.31592219
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
#    Sample_name                                      taxa.id Subject.ID      exp
# 1     SC555338                    f__Bacillaceaeg__Bacillus      D6311 1.20e-02
# 2     SC555351                    f__Bacillaceaeg__Bacillus      D6311 1.20e-02
# 3     SC555338 f__Enterobacteriaceaeg__Escherichia.Shigella      D6311 6.90e-04
# 4     SC555351 f__Enterobacteriaceaeg__Escherichia.Shigella      D6311 6.90e-04
# 5     SC555338           f__Enterobacteriaceaeg__Salmonella      D6311 7.00e-04
# 6     SC555351           f__Enterobacteriaceaeg__Salmonella      D6311 7.00e-04
# 7     SC555338            f__Enterococcaceaeg__Enterococcus      D6311 1.34e-05
# 8     SC555351            f__Enterococcaceaeg__Enterococcus      D6311 1.34e-05
# 9     SC555338          f__Lactobacillaceaeg__Lactobacillus      D6311 1.20e-04
# 10    SC555351          f__Lactobacillaceaeg__Lactobacillus      D6311 1.20e-04
# 11    SC555338                   f__Listeriaceaeg__Listeria      D6311 9.59e-01
# 12    SC555351                   f__Listeriaceaeg__Listeria      D6311 9.59e-01
# 13    SC555338            f__Pseudomonadaceaeg__Pseudomonas      D6311 2.80e-02
# 14    SC555351            f__Pseudomonadaceaeg__Pseudomonas      D6311 2.80e-02
# 15    SC555338        f__Staphylococcaceaeg__Staphylococcus      D6311 1.00e-06
# 16    SC555351        f__Staphylococcaceaeg__Staphylococcus      D6311 1.00e-06
#                 bench       obs
# 1  blast_cl_gg_gg.qza 0.1919275
# 2  blast_cl_gg_gg.qza 0.2132834
# 3  blast_cl_gg_gg.qza 0.0000000
# 4  blast_cl_gg_gg.qza 0.0000000
# 5  blast_cl_gg_gg.qza 0.0000000
# 6  blast_cl_gg_gg.qza 0.0000000
# 7  blast_cl_gg_gg.qza 0.0000000
# 8  blast_cl_gg_gg.qza 0.0000000
# 9  blast_cl_gg_gg.qza 0.0000000
# 10 blast_cl_gg_gg.qza 0.0000000
# 11 blast_cl_gg_gg.qza 0.0000000
# 12 blast_cl_gg_gg.qza 0.0000000
# 13 blast_cl_gg_gg.qza 0.7883031
# 14 blast_cl_gg_gg.qza 0.7745557
# 15 blast_cl_gg_gg.qza 0.0000000
# 16 blast_cl_gg_gg.qza 0.0000000
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# "Removed 10 rows containing non-finite values (stat_smooth)."
# Warning message:
# "Removed 10 rows containing non-finite values (stat_cor)."
# Warning message:
# "Removed 10 rows containing missing values (geom_point)."
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# "Removed 10 rows containing non-finite values (stat_smooth)."
# Warning message:
# "Removed 10 rows containing non-finite values (stat_cor)."
# Warning message:
# "Removed 10 rows containing missing values (geom_point)."
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# "Removed 20 rows containing non-finite values (stat_smooth)."
# Warning message:
# "Removed 20 rows containing non-finite values (stat_cor)."
# Warning message:
# "Removed 20 rows containing missing values (geom_point)."
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# "Removed 20 rows containing non-finite values (stat_smooth)."
# Warning message:
# "Removed 20 rows containing non-finite values (stat_cor)."
# Warning message:
# "Removed 20 rows containing missing values (geom_point)."
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# "Removed 15 rows containing non-finite values (stat_smooth)."
# Warning message:
# "Removed 15 rows containing non-finite values (stat_cor)."
# Warning message:
# "Removed 15 rows containing missing values (geom_point)."
# `geom_smooth()` using formula 'y ~ x'
#
# ...
# 65    MSA1003 0.18000 vsearch_op_SILVA_silva.qza 1.572827e-01
# 66    MSA1003 0.00180 vsearch_op_SILVA_silva.qza 0.000000e+00
# 67    MSA1003 0.00180 vsearch_op_SILVA_silva.qza 0.000000e+00
# 68    MSA1003 0.00180 vsearch_op_SILVA_silva.qza 0.000000e+00
# 69    MSA1003 0.00180 vsearch_op_SILVA_silva.qza 0.000000e+00
# 70    MSA1003 0.00180 vsearch_op_SILVA_silva.qza 0.000000e+00
# 71    MSA1003 0.01800 vsearch_op_SILVA_silva.qza 3.792953e-03
# 72    MSA1003 0.01800 vsearch_op_SILVA_silva.qza 2.889236e-03
# 73    MSA1003 0.01800 vsearch_op_SILVA_silva.qza 3.489494e-03
# 74    MSA1003 0.01800 vsearch_op_SILVA_silva.qza 4.094166e-03
# 75    MSA1003 0.01800 vsearch_op_SILVA_silva.qza 4.453269e-03
# 76    MSA1003 0.18000 vsearch_op_SILVA_silva.qza 1.425530e-02
# 77    MSA1003 0.18000 vsearch_op_SILVA_silva.qza 1.249142e-02
# 78    MSA1003 0.18000 vsearch_op_SILVA_silva.qza 1.397965e-02
# 79    MSA1003 0.18000 vsearch_op_SILVA_silva.qza 1.526007e-02
# 80    MSA1003 0.18000 vsearch_op_SILVA_silva.qza 1.548716e-02
# 81    MSA1003 0.19800 vsearch_op_SILVA_silva.qza 2.403519e-01
# 82    MSA1003 0.19800 vsearch_op_SILVA_silva.qza 2.010642e-01
# 83    MSA1003 0.19800 vsearch_op_SILVA_silva.qza 2.381525e-01
# 84    MSA1003 0.19800 vsearch_op_SILVA_silva.qza 2.135170e-01
# 85    MSA1003 0.19800 vsearch_op_SILVA_silva.qza 2.108921e-01
# 86    MSA1003 0.19800 vsearch_op_SILVA_silva.qza 1.074717e-01
# 87    MSA1003 0.19800 vsearch_op_SILVA_silva.qza 1.397704e-01
# 88    MSA1003 0.19800 vsearch_op_SILVA_silva.qza 9.960228e-02
# 89    MSA1003 0.19800 vsearch_op_SILVA_silva.qza 1.561366e-01
# 90    MSA1003 0.19800 vsearch_op_SILVA_silva.qza 1.560062e-01
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
#    Sample_name                                          taxa.id Subject.ID
# 1     SC284728                    D_4__BacillaceaeD_5__Bacillus      D6305
# 2     SC284734                    D_4__BacillaceaeD_5__Bacillus      D6305
# 3     SC326767                    D_4__BacillaceaeD_5__Bacillus      D6305
# 4     SC555340                    D_4__BacillaceaeD_5__Bacillus      D6305
# 5     SC555348                    D_4__BacillaceaeD_5__Bacillus      D6305
# 6     SC284728 D_4__EnterobacteriaceaeD_5__Escherichia.Shigella      D6305
# 7     SC284734 D_4__EnterobacteriaceaeD_5__Escherichia.Shigella      D6305
# 8     SC326767 D_4__EnterobacteriaceaeD_5__Escherichia.Shigella      D6305
# 9     SC555340 D_4__EnterobacteriaceaeD_5__Escherichia.Shigella      D6305
# 10    SC555348 D_4__EnterobacteriaceaeD_5__Escherichia.Shigella      D6305
# 11    SC284728           D_4__EnterobacteriaceaeD_5__Salmonella      D6305
# 12    SC284734           D_4__EnterobacteriaceaeD_5__Salmonella      D6305
# 13    SC326767           D_4__EnterobacteriaceaeD_5__Salmonella      D6305
# 14    SC555340           D_4__EnterobacteriaceaeD_5__Salmonella      D6305
# 15    SC555348           D_4__EnterobacteriaceaeD_5__Salmonella      D6305
# 16    SC284728            D_4__EnterococcaceaeD_5__Enterococcus      D6305
# 17    SC284734            D_4__EnterococcaceaeD_5__Enterococcus      D6305
# 18    SC326767            D_4__EnterococcaceaeD_5__Enterococcus      D6305
# 19    SC555340            D_4__EnterococcaceaeD_5__Enterococcus      D6305
# 20    SC555348            D_4__EnterococcaceaeD_5__Enterococcus      D6305
# 21    SC284728          D_4__LactobacillaceaeD_5__Lactobacillus      D6305
# 22    SC284734          D_4__LactobacillaceaeD_5__Lactobacillus      D6305
# 23    SC326767          D_4__LactobacillaceaeD_5__Lactobacillus      D6305
# 24    SC555340          D_4__LactobacillaceaeD_5__Lactobacillus      D6305
# 25    SC555348          D_4__LactobacillaceaeD_5__Lactobacillus      D6305
# 26    SC284728                   D_4__ListeriaceaeD_5__Listeria      D6305
# 27    SC284734                   D_4__ListeriaceaeD_5__Listeria      D6305
# 28    SC326767                   D_4__ListeriaceaeD_5__Listeria      D6305
# 29    SC555340                   D_4__ListeriaceaeD_5__Listeria      D6305
# 30    SC555348                   D_4__ListeriaceaeD_5__Listeria      D6305
# 31    SC284728            D_4__PseudomonadaceaeD_5__Pseudomonas      D6305
# 32    SC284734            D_4__PseudomonadaceaeD_5__Pseudomonas      D6305
# 33    SC326767            D_4__PseudomonadaceaeD_5__Pseudomonas      D6305
# 34    SC555340            D_4__PseudomonadaceaeD_5__Pseudomonas      D6305
# 35    SC555348            D_4__PseudomonadaceaeD_5__Pseudomonas      D6305
# 36    SC284728        D_4__StaphylococcaceaeD_5__Staphylococcus      D6305
# 37    SC284734        D_4__StaphylococcaceaeD_5__Staphylococcus      D6305
# 38    SC326767        D_4__StaphylococcaceaeD_5__Staphylococcus      D6305
# 39    SC555340        D_4__StaphylococcaceaeD_5__Staphylococcus      D6305
# 40    SC555348        D_4__StaphylococcaceaeD_5__Staphylococcus      D6305
#      exp                      bench        obs
# 1  0.174 vsearch_op_SILVA_silva.qza 0.16198952
# 2  0.174 vsearch_op_SILVA_silva.qza 0.18198915
# 3  0.174 vsearch_op_SILVA_silva.qza 0.16570333
# 4  0.174 vsearch_op_SILVA_silva.qza 0.17923074
# 5  0.174 vsearch_op_SILVA_silva.qza 0.20502707
# 6  0.101 vsearch_op_SILVA_silva.qza 0.09300116
# 7  0.101 vsearch_op_SILVA_silva.qza 0.09354360
# 8  0.101 vsearch_op_SILVA_silva.qza 0.08086175
# 9  0.101 vsearch_op_SILVA_silva.qza 0.08651352
# 10 0.101 vsearch_op_SILVA_silva.qza 0.07908082
# 11 0.104 vsearch_op_SILVA_silva.qza 0.11796397
# 12 0.104 vsearch_op_SILVA_silva.qza 0.11890924
# 13 0.104 vsearch_op_SILVA_silva.qza 0.12425074
# 14 0.104 vsearch_op_SILVA_silva.qza 0.13069143
# 15 0.104 vsearch_op_SILVA_silva.qza 0.12403538
# 16 0.099 vsearch_op_SILVA_silva.qza 0.10148877
# 17 0.099 vsearch_op_SILVA_silva.qza 0.09722553
# 18 0.099 vsearch_op_SILVA_silva.qza 0.08959014
# 19 0.099 vsearch_op_SILVA_silva.qza 0.09628906
# 20 0.099 vsearch_op_SILVA_silva.qza 0.07893383
# 21 0.184 vsearch_op_SILVA_silva.qza 0.05836323
# 22 0.184 vsearch_op_SILVA_silva.qza 0.06119929
# 23 0.184 vsearch_op_SILVA_silva.qza 0.06507862
# 24 0.184 vsearch_op_SILVA_silva.qza 0.09181487
# 25 0.184 vsearch_op_SILVA_silva.qza 0.07383816
# 26 0.141 vsearch_op_SILVA_silva.qza 0.18691484
# 27 0.141 vsearch_op_SILVA_silva.qza 0.17762748
# 28 0.141 vsearch_op_SILVA_silva.qza 0.16827222
# 29 0.141 vsearch_op_SILVA_silva.qza 0.16949280
# 30 0.141 vsearch_op_SILVA_silva.qza 0.18297851
# 31 0.042 vsearch_op_SILVA_silva.qza 0.04916311
# 32 0.042 vsearch_op_SILVA_silva.qza 0.04606374
# 33 0.042 vsearch_op_SILVA_silva.qza 0.06425152
# 34 0.042 vsearch_op_SILVA_silva.qza 0.04459150
# 35 0.042 vsearch_op_SILVA_silva.qza 0.05257356
# 36 0.155 vsearch_op_SILVA_silva.qza 0.23111539
# 37 0.155 vsearch_op_SILVA_silva.qza 0.22344198
# 38 0.155 vsearch_op_SILVA_silva.qza 0.24199167
# 39 0.155 vsearch_op_SILVA_silva.qza 0.20137610
# 40 0.155 vsearch_op_SILVA_silva.qza 0.20353267
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
#    Sample_name                                          taxa.id Subject.ID
# 1     SC284729                    D_4__BacillaceaeD_5__Bacillus      D6306
# 2     SC284735                    D_4__BacillaceaeD_5__Bacillus      D6306
# 3     SC326768                    D_4__BacillaceaeD_5__Bacillus      D6306
# 4     SC555344                    D_4__BacillaceaeD_5__Bacillus      D6306
# 5     SC555345                    D_4__BacillaceaeD_5__Bacillus      D6306
# 6     SC284729 D_4__EnterobacteriaceaeD_5__Escherichia.Shigella      D6306
# 7     SC284735 D_4__EnterobacteriaceaeD_5__Escherichia.Shigella      D6306
# 8     SC326768 D_4__EnterobacteriaceaeD_5__Escherichia.Shigella      D6306
# 9     SC555344 D_4__EnterobacteriaceaeD_5__Escherichia.Shigella      D6306
# 10    SC555345 D_4__EnterobacteriaceaeD_5__Escherichia.Shigella      D6306
# 11    SC284729           D_4__EnterobacteriaceaeD_5__Salmonella      D6306
# 12    SC284735           D_4__EnterobacteriaceaeD_5__Salmonella      D6306
# 13    SC326768           D_4__EnterobacteriaceaeD_5__Salmonella      D6306
# 14    SC555344           D_4__EnterobacteriaceaeD_5__Salmonella      D6306
# 15    SC555345           D_4__EnterobacteriaceaeD_5__Salmonella      D6306
# 16    SC284729            D_4__EnterococcaceaeD_5__Enterococcus      D6306
# 17    SC284735            D_4__EnterococcaceaeD_5__Enterococcus      D6306
# 18    SC326768            D_4__EnterococcaceaeD_5__Enterococcus      D6306
# 19    SC555344            D_4__EnterococcaceaeD_5__Enterococcus      D6306
# 20    SC555345            D_4__EnterococcaceaeD_5__Enterococcus      D6306
# 21    SC284729          D_4__LactobacillaceaeD_5__Lactobacillus      D6306
# 22    SC284735          D_4__LactobacillaceaeD_5__Lactobacillus      D6306
# 23    SC326768          D_4__LactobacillaceaeD_5__Lactobacillus      D6306
# 24    SC555344          D_4__LactobacillaceaeD_5__Lactobacillus      D6306
# 25    SC555345          D_4__LactobacillaceaeD_5__Lactobacillus      D6306
# 26    SC284729                   D_4__ListeriaceaeD_5__Listeria      D6306
# 27    SC284735                   D_4__ListeriaceaeD_5__Listeria      D6306
# 28    SC326768                   D_4__ListeriaceaeD_5__Listeria      D6306
# 29    SC555344                   D_4__ListeriaceaeD_5__Listeria      D6306
# 30    SC555345                   D_4__ListeriaceaeD_5__Listeria      D6306
# 31    SC284729            D_4__PseudomonadaceaeD_5__Pseudomonas      D6306
# 32    SC284735            D_4__PseudomonadaceaeD_5__Pseudomonas      D6306
# 33    SC326768            D_4__PseudomonadaceaeD_5__Pseudomonas      D6306
# 34    SC555344            D_4__PseudomonadaceaeD_5__Pseudomonas      D6306
# 35    SC555345            D_4__PseudomonadaceaeD_5__Pseudomonas      D6306
# 36    SC284729        D_4__StaphylococcaceaeD_5__Staphylococcus      D6306
# 37    SC284735        D_4__StaphylococcaceaeD_5__Staphylococcus      D6306
# 38    SC326768        D_4__StaphylococcaceaeD_5__Staphylococcus      D6306
# 39    SC555344        D_4__StaphylococcaceaeD_5__Staphylococcus      D6306
# 40    SC555345        D_4__StaphylococcaceaeD_5__Staphylococcus      D6306
#      exp                      bench        obs
# 1  0.174 vsearch_op_SILVA_silva.qza 0.16022399
# 2  0.174 vsearch_op_SILVA_silva.qza 0.18211794
# 3  0.174 vsearch_op_SILVA_silva.qza 0.16003020
# 4  0.174 vsearch_op_SILVA_silva.qza 0.13905785
# 5  0.174 vsearch_op_SILVA_silva.qza 0.17217795
# 6  0.101 vsearch_op_SILVA_silva.qza 0.06809215
# 7  0.101 vsearch_op_SILVA_silva.qza 0.06772049
# 8  0.101 vsearch_op_SILVA_silva.qza 0.06928156
# 9  0.101 vsearch_op_SILVA_silva.qza 0.08525953
# 10 0.101 vsearch_op_SILVA_silva.qza 0.07473176
# 11 0.104 vsearch_op_SILVA_silva.qza 0.10619229
# 12 0.104 vsearch_op_SILVA_silva.qza 0.10436316
# 13 0.104 vsearch_op_SILVA_silva.qza 0.10534710
# 14 0.104 vsearch_op_SILVA_silva.qza 0.13101514
# 15 0.104 vsearch_op_SILVA_silva.qza 0.11294472
# 16 0.099 vsearch_op_SILVA_silva.qza 0.11351403
# 17 0.099 vsearch_op_SILVA_silva.qza 0.10821913
# 18 0.099 vsearch_op_SILVA_silva.qza 0.10773942
# 19 0.099 vsearch_op_SILVA_silva.qza 0.08850365
# 20 0.099 vsearch_op_SILVA_silva.qza 0.10152475
# 21 0.184 vsearch_op_SILVA_silva.qza 0.09023362
# 22 0.184 vsearch_op_SILVA_silva.qza 0.08521476
# 23 0.184 vsearch_op_SILVA_silva.qza 0.09523556
# 24 0.184 vsearch_op_SILVA_silva.qza 0.10398081
# 25 0.184 vsearch_op_SILVA_silva.qza 0.12690594
# 26 0.141 vsearch_op_SILVA_silva.qza 0.17866392
# 27 0.141 vsearch_op_SILVA_silva.qza 0.17088961
# 28 0.141 vsearch_op_SILVA_silva.qza 0.16949315
# 29 0.141 vsearch_op_SILVA_silva.qza 0.15619086
# 30 0.141 vsearch_op_SILVA_silva.qza 0.14538495
# 31 0.042 vsearch_op_SILVA_silva.qza 0.05715022
# 32 0.042 vsearch_op_SILVA_silva.qza 0.05724802
# 33 0.042 vsearch_op_SILVA_silva.qza 0.06092439
# 34 0.042 vsearch_op_SILVA_silva.qza 0.05822520
# 35 0.042 vsearch_op_SILVA_silva.qza 0.05725670
# 36 0.155 vsearch_op_SILVA_silva.qza 0.22592979
# 37 0.155 vsearch_op_SILVA_silva.qza 0.21984510
# 38 0.155 vsearch_op_SILVA_silva.qza 0.23194862
# 39 0.155 vsearch_op_SILVA_silva.qza 0.23776696
# 40 0.155 vsearch_op_SILVA_silva.qza 0.20891636
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
#    Sample_name                                          taxa.id Subject.ID
# 1     SC555338                    D_4__BacillaceaeD_5__Bacillus      D6311
# 2     SC555351                    D_4__BacillaceaeD_5__Bacillus      D6311
# 3     SC555338 D_4__EnterobacteriaceaeD_5__Escherichia.Shigella      D6311
# 4     SC555351 D_4__EnterobacteriaceaeD_5__Escherichia.Shigella      D6311
# 5     SC555338           D_4__EnterobacteriaceaeD_5__Salmonella      D6311
# 6     SC555351           D_4__EnterobacteriaceaeD_5__Salmonella      D6311
# 7     SC555338            D_4__EnterococcaceaeD_5__Enterococcus      D6311
# 8     SC555351            D_4__EnterococcaceaeD_5__Enterococcus      D6311
# 9     SC555338          D_4__LactobacillaceaeD_5__Lactobacillus      D6311
# 10    SC555351          D_4__LactobacillaceaeD_5__Lactobacillus      D6311
# 11    SC555338                   D_4__ListeriaceaeD_5__Listeria      D6311
# 12    SC555351                   D_4__ListeriaceaeD_5__Listeria      D6311
# 13    SC555338            D_4__PseudomonadaceaeD_5__Pseudomonas      D6311
# 14    SC555351            D_4__PseudomonadaceaeD_5__Pseudomonas      D6311
# 15    SC555338        D_4__StaphylococcaceaeD_5__Staphylococcus      D6311
# 16    SC555351        D_4__StaphylococcaceaeD_5__Staphylococcus      D6311
#         exp                      bench          obs
# 1  1.20e-02 vsearch_op_SILVA_silva.qza 0.0116599109
# 2  1.20e-02 vsearch_op_SILVA_silva.qza 0.0124304874
# 3  6.90e-04 vsearch_op_SILVA_silva.qza 0.0012010209
# 4  6.90e-04 vsearch_op_SILVA_silva.qza 0.0007087559
# 5  7.00e-04 vsearch_op_SILVA_silva.qza 0.0009508082
# 6  7.00e-04 vsearch_op_SILVA_silva.qza 0.0010086141
# 7  1.34e-05 vsearch_op_SILVA_silva.qza 0.0000000000
# 8  1.34e-05 vsearch_op_SILVA_silva.qza 0.0000000000
# 9  1.20e-04 vsearch_op_SILVA_silva.qza 0.0000000000
# 10 1.20e-04 vsearch_op_SILVA_silva.qza 0.0000000000
# 11 9.59e-01 vsearch_op_SILVA_silva.qza 0.9382975529
# 12 9.59e-01 vsearch_op_SILVA_silva.qza 0.9407098463
# 13 2.80e-02 vsearch_op_SILVA_silva.qza 0.0478907071
# 14 2.80e-02 vsearch_op_SILVA_silva.qza 0.0451422964
# 15 1.00e-06 vsearch_op_SILVA_silva.qza 0.0000000000
# 16 1.00e-06 vsearch_op_SILVA_silva.qza 0.0000000000
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
# Warning message in cor.test.default(my_data$obs, my_data$exp, method = "spearman"):
# "Cannot compute exact p-value with ties"
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# "Removed 5 rows containing non-finite values (stat_smooth)."
# Warning message:
# "Removed 5 rows containing non-finite values (stat_cor)."
# Warning message:
# "Removed 5 rows containing missing values (geom_point)."
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# "Removed 5 rows containing non-finite values (stat_smooth)."
# Warning message:
# "Removed 5 rows containing non-finite values (stat_cor)."
# Warning message:
# "Removed 5 rows containing missing values (geom_point)."
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# "Removed 10 rows containing non-finite values (stat_smooth)."
# Warning message:
# "Removed 10 rows containing non-finite values (stat_cor)."
# Warning message:
# "Removed 10 rows containing missing values (geom_point)."
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# "Removed 10 rows containing non-finite values (stat_smooth)."
# Warning message:
# "Removed 10 rows containing non-finite values (stat_cor)."
# Warning message:
# "Removed 10 rows containing missing values (geom_point)."
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
#
# Saving 6.67 x 6.67 in image

# %%
write.csv(EOdf_stats_merged,paste(out_dir,"bench_files/EO_stats_summary.csv",sep=""))
write.csv(mergedf_f1stats,paste(out_dir,"bench_files/F1_stats_summary.csv",sep=""))

# %% [markdown]
# <h2> Benchmarked Assessment<h2>

# %%
Distdf_merged=data.frame()
#Silva
if(length(test_list)>1){
    RAdf_oe = RAdf_addcontrols("CONTdf_s","dissdf_s")
    RAdf_clean = calc_dist(RAdf_oe,CONTdf_s)
    plot_dist_cluster(RAdf_clean,"s")
    Distdf = plot_dist_violin(RAdf_clean,"s")
} 
Distdf_merged = bind_rows(Distdf_merged,Distdf)

#GreenGenes
RAdf_oe = RAdf_addcontrols("CONTdf_g","dissdf_g")
RAdf_clean = calc_dist(RAdf_oe,CONTdf_g)
plot_dist_cluster(RAdf_clean,"g")
Distdf = plot_dist_violin(RAdf_clean,"g")
Distdf_merged = bind_rows(Distdf_merged,Distdf)
# Out:
# Saving 6.67 x 6.67 in image
# png
#   2
# Saving 6.67 x 6.67 in image

# %%
adonis_stats = adonis_bc(Distdf_merged)
adonis_stats
# Out:
#   level      comparison  pval sig homo_s homo_g
# 1 tax.ref    bray-curtis 0.01 sig NA            NA
# 2 tax.type   bray-curtis 0.65 ns  NA            NA
# 3 group.type bray-curtis 1.00 ns  NA            NA
# 4 NA         NA            NA NA   1            NA
# 5 NA         NA            NA NA  NA     0.9999574

# %%
#Overall violin plots
x_list = c("TAR","TDR","F1")
y_labs = c("Taxonmic Accuracy Rate","Taxonmic Detection Rate", "F-Measure")

#Create violin plots collapsed to the group.type (merges all ref dbs, and tax class methods)
plot_f1_violin(mergedf_f1stats,x_list,y_labs,"group.type","Group Types","summary")

#Create violin plots collapsed to the tax.type (merges all ref dbs, and grouping methods)
plot_f1_violin(mergedf_f1stats,x_list,y_labs,"tax.type","Tax Types","summary")

#Create violin plots collapsed to the tax.ref (merges all tax class methods and grouping methods)
plot_f1_violin(mergedf_f1stats,x_list,y_labs,"tax.ref","Tax Ref Types","summary")

#Create violin plots for all binf variations (merges all variables)
plot_f1_violin(mergedf_f1stats,x_list,y_labs,"bmark","All Grouping and Assignment Variables","summary")

# %%
#T-tests
tstatdf_merged=data.frame()
variable_list = c("group.type","tax.type","tax.ref")

for (variable in variable_list){
    tstatdf = tstat_paired_f1(mergedf_f1stats,variable)
    tstatdf_merged=bind_rows(tstatdf_merged,tstatdf)  
}
write.csv(tstatdf_merged,paste(out_dir,"bench_files/ttest_stats.csv",sep=""))
